# %% [markdown]
# # Ethical Considerations in Prompt Engineering
# ### Overview
# This tutorial explores the ethical dimensions of prompt engineering, focusing on two critical aspects: avoiding biases in prompts and creating inclusive and fair prompts. As AI language models become increasingly integrated into various applications, ensuring ethical use becomes paramount.
#
# ### Motivation
# AI language models, trained on vast amounts of data, can inadvertently perpetuate or amplify existing biases. Prompt engineers play a crucial role in mitigating these biases and promoting fairness. This tutorial aims to equip learners with the knowledge and tools to create more ethical and inclusive prompts.
#
# ### Key Components
# 1. Understanding biases in AI
# 2. Techniques for identifying biases in prompts
# 3. Strategies for creating inclusive prompts
# 4. Methods for evaluating fairness in AI outputs
# 5. Practical examples and exercises
# ### Method Details
# This tutorial employs a combination of theoretical explanations and practical demonstrations:
#
# 1. We begin by setting up the necessary environment, including the OpenAI API and LangChain library.
# 2. We explore common types of biases in AI and how they can manifest in prompts.
# 3. Through examples, we demonstrate how to identify and mitigate biases in prompts.
# 4. We introduce techniques for creating inclusive prompts that consider diverse perspectives.
# 5. We implement methods to evaluate the fairness of AI-generated outputs.
# 6. Throughout the tutorial, we provide exercises for hands-on learning and application of ethical prompt engineering principles.
# ### Conclusion
# By the end of this tutorial, learners will have gained:
#
# 1. An understanding of the ethical implications of prompt engineering
# 2. Skills to identify and mitigate biases in prompts
# 3. Techniques for creating inclusive and fair prompts
# 4. Methods to evaluate and improve the ethical quality of AI outputs
# 5. Practical experience in applying ethical considerations to real-world prompt engineering scenarios
#
# This knowledge will empower prompt engineers to create more responsible and equitable AI applications, contributing to the development of AI systems that benefit all members of society.
#
# ### Setup
# First, let's import the necessary libraries and set up our environment.

# %%
import os
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# Load enviroment variables
from dotenv import load_dotenv
load_dotenv()

# Set up Google API key
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# Initialize the language model
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

def get_model_response(prompt):
    """Helper function to get model response."""
    return llm.invoke(prompt).content

# %% [markdown]
# ### Understanding Biases in AI
# Let's start by examining how biases can manifest in AI responses. We'll use a potentially biased prompt and analyze the output.

# %%
biased_prompt = "Describe a typical programmer."
biased_response = get_model_response(biased_prompt)
print("Potentially biased response:")
print(biased_response)
# Out:
# Potentially biased response:
# Okay, there's no single "typical" programmer. The field is incredibly diverse. However, we can paint a picture based on common traits, skills, and work habits you might find across many programmers.  Keep in mind this is a stereotype, and real-life programmers will vary significantly!
#
# **General Traits & Personality:**
#
# *   **Problem Solver:** At their core, programmers are problem solvers. They enjoy breaking down complex issues into smaller, manageable steps and finding logical solutions.
# *   **Logical Thinker:** A strong aptitude for logical reasoning is essential. They need to understand how code executes step-by-step and predict the outcome of different code paths.
# *   **Detail-Oriented:** Even a small typo can break an entire program. Programmers need to be meticulous and pay close attention to detail.
# *   **Persistent:** Debugging is a significant part of the job. Programmers need to be persistent and patient when tracking down and fixing errors. They can't give up easily.
# *   **Curious & Lifelong Learners:** Technology changes rapidly. Programmers need to be curious and willing to learn new languages, frameworks, and tools throughout their careers.
# *   **Independent & Collaborative:** They often work independently on individual tasks but also need to collaborate effectively with other developers, designers, and stakeholders.
# *   **Abstract Thinkers:** They can understand and manipulate abstract concepts like data structures, algorithms, and design patterns.
# *   **Communication Skills:** While sometimes stereotyped as being poor communicators, good programmers understand the importance of clear communication, especially when explaining technical concepts to non-technical people or collaborating on a team.
#
# **Skills & Knowledge:**
#
# *   **Proficiency in one or more Programming Languages:** This is the foundation. Common languages include Python, Java, JavaScript, C++, C#, Go, Ruby, and many others. The choice of language often depends on the type of work they do.
# *   **Understanding of Data Structures and Algorithms:** They need to know how to organize and manipulate data efficiently.
# *   **Familiarity with Software Development Methodologies:** Agile, Scrum, Waterfall, etc. They need to understand how software is developed in a team environment.
# *   **Version Control (e.g., Git):** Essential for managing code changes and collaborating with others.
# *   **Debugging Skills:** The ability to identify and fix errors in code.
# *   **Testing:** Writing unit tests and integration tests to ensure code quality.
# *   **Operating Systems:** Knowledge of how operating systems work (Windows, macOS, Linux).
# *   **Databases:** Understanding of database concepts and how to interact with databases (SQL, NoSQL).
# *   **Software Design Principles:** Understanding design patterns, SOLID principles, and other concepts to create maintainable and scalable code.
# *   **Problem Decomposition:** The ability to break a large problem into smaller, manageable parts.
# *   **Comfort with Command Line/Terminal:** Often used for interacting with systems and running commands.
#
# **Work Habits & Environment:**
#
# *   **Spends a lot of time in front of a computer:** This is unavoidable.
# *   **Uses a variety of tools:** IDEs (Integrated Development Environments), text editors, debuggers, profilers, etc.
# *   **Participates in code reviews:** Reviewing other people's code to ensure quality and consistency.
# *   **Attends meetings (sometimes too many):** To discuss project progress, requirements, and issues.
# *   **Constantly learning:** Reading documentation, attending conferences, taking online courses.
# *   **Works in a variety of environments:** From large corporations to small startups to freelance.
# *   **May work remotely:** Remote work is increasingly common in the software industry.
# *   **May have unconventional work hours:** Depending on deadlines and project requirements.
# *   **Uses online resources extensively:** Stack Overflow, documentation websites, online forums.
#
# **Stereotypes (to be taken with a grain of salt):**
#
# *   **Loves coffee or energy drinks:** To stay focused and alert.
# *   **Enjoys video games:** A common hobby, perhaps due to the problem-solving aspect.
# *   **Wears glasses:** Due to spending long hours in front of a screen.
# *   **Has a quirky sense of humor:** Often related to technology or coding.
# *   **Can be socially awkward:** This is a harmful stereotype, but sometimes programmers are more focused on technical details than social interactions.
# *   **Prefers dark mode:** On everything.
# *   **Is obsessed with optimizing things:** Even when it's not necessary.
#
# **In summary:**
#
# A typical programmer is a logical, detail-oriented, and persistent problem solver who is constantly learning and adapting to new technologies. They are proficient in one or more programming languages and have a strong understanding of software development principles. They work in a variety of environments and use a variety of tools to create software. While stereotypes exist, the field is diverse, and programmers come from all walks of life. The key is a passion for solving problems with code.

# %% [markdown]
# ### Identifying and Mitigating Biases
# Now, let's create a more inclusive prompt and compare the results.

# %%
inclusive_prompt = PromptTemplate(
    input_variables=["profession"],
    template="Describe the diverse range of individuals who work as {profession}, emphasizing the variety in their backgrounds, experiences, and characteristics."
)

inclusive_response = (inclusive_prompt | llm).invoke({"profession": "computer programmers"}).content
print("More inclusive response:")
print(inclusive_response)
# Out:
# More inclusive response:
# The stereotype of a computer programmer as a young, male, hoodie-wearing introvert glued to a screen is a relic of the past. Today, the field is becoming increasingly diverse, encompassing individuals from a wide array of backgrounds, experiences, and characteristics. Here's a glimpse into the diverse range of people who code:
#
# **Diversity in Demographics:**
#
# *   **Gender:** While historically male-dominated, there's a growing push for and increase in female programmers. Initiatives and communities are actively working to encourage and support women in STEM fields.
# *   **Age:** Programmers range from teenagers self-taught in online courses to seasoned professionals with decades of experience. Some are career changers who discovered their passion for coding later in life.
# *   **Race and Ethnicity:** Programmers come from all racial and ethnic backgrounds, reflecting the global nature of the tech industry.
# *   **Socioeconomic Background:** Individuals from diverse socioeconomic backgrounds are finding opportunities in programming, often through coding bootcamps, scholarships, and online resources that democratize access to education.
# *   **Sexual Orientation and Gender Identity:** The programming community is becoming more inclusive and welcoming to LGBTQ+ individuals, with organizations dedicated to fostering a safe and supportive environment.
# *   **Ability:** Programmers with disabilities are making significant contributions, utilizing assistive technologies and advocating for accessibility in software development.
#
# **Diversity in Educational Background:**
#
# *   **Computer Science Degrees:** Many programmers hold traditional computer science degrees from universities.
# *   **Related STEM Degrees:** Individuals with backgrounds in mathematics, physics, engineering, and other STEM fields often transition into programming roles.
# *   **Non-STEM Degrees:** Surprisingly, programmers come from diverse academic backgrounds like humanities, arts, and social sciences. They bring unique perspectives and problem-solving skills to the field.
# *   **Coding Bootcamps:** Intensive coding bootcamps offer a fast-track to programming careers, attracting individuals with diverse educational backgrounds and work experiences.
# *   **Self-Taught Programmers:** Many programmers are entirely self-taught, learning through online courses, tutorials, and personal projects.
#
# **Diversity in Experience:**
#
# *   **Entry-Level Programmers:** Fresh graduates and bootcamp attendees are starting their careers, eager to learn and contribute.
# *   **Mid-Level Programmers:** Experienced programmers are taking on more complex projects, mentoring junior developers, and specializing in specific technologies.
# *   **Senior Programmers:** Seasoned professionals are leading teams, designing architectures, and making strategic decisions.
# *   **Full-Stack Developers:** These versatile programmers can handle both front-end and back-end development.
# *   **Specialized Developers:** Programmers often specialize in areas like web development, mobile development, data science, game development, embedded systems, and more.
# *   **Career Changers:** Individuals from various industries, like healthcare, finance, and education, are transitioning into programming careers, bringing valuable domain expertise.
#
# **Diversity in Personality and Characteristics:**
#
# *   **Introverts and Extroverts:** While introversion is sometimes associated with programmers, extroverts thrive in collaborative environments and excel in communication and teamwork.
# *   **Creative and Analytical Thinkers:** Programming requires both analytical problem-solving skills and creative thinking to design innovative solutions.
# *   **Detail-Oriented and Big-Picture Thinkers:** Programmers need to pay attention to detail while also understanding the overall goals and architecture of a project.
# *   **Collaborative and Independent Workers:** Depending on the project, programmers may work independently or as part of a team.
# *   **Lifelong Learners:** The tech industry is constantly evolving, so programmers must be committed to continuous learning and adapting to new technologies.
# *   **Passionate Problem Solvers:** At the heart of every programmer is a love for solving problems and creating innovative solutions.
#
# **In conclusion, the world of computer programming is a vibrant and diverse ecosystem. It is no longer defined by a single stereotype. The field welcomes individuals from all walks of life who possess a passion for technology, a willingness to learn, and a desire to create.** This diversity of backgrounds, experiences, and perspectives is crucial for innovation and ensures that technology is developed to meet the needs of a diverse global population.

# %% [markdown]
# ### Creating Inclusive Prompts
# Let's explore techniques for creating prompts that encourage diverse and inclusive responses.

# %%
def create_inclusive_prompt(topic):
    """Creates an inclusive prompt template for a given topic."""
    return PromptTemplate(
        input_variables=["topic"],
        template="Provide a balanced and inclusive perspective on {topic}, considering diverse viewpoints, experiences, and cultural contexts."
    )

topics = ["leadership", "family structures", "beauty standards"]

for topic in topics:
    prompt = create_inclusive_prompt(topic)
    response = (prompt | llm).invoke({"topic": topic}).content
    print(f"Inclusive perspective on {topic}:")
    print(response)
    print("\n" + "-"*50 + "\n")
# Out:
# Inclusive perspective on leadership:
# ## A Balanced and Inclusive Perspective on Leadership
#
# Leadership is not a monolithic concept. It's a multifaceted, dynamic process that evolves based on context, culture, and the individuals involved.  A truly balanced and inclusive perspective on leadership acknowledges that:
#
# **1. Leadership is not limited to a single style or personality type:**
#
# *   **Beyond the "Heroic Leader":**  We need to move away from the outdated notion of the charismatic, top-down "heroic" leader.  This model often privileges extroverted, assertive personalities, excluding valuable contributions from introverted, collaborative, or reflective individuals.
# *   **Diverse Leadership Styles:**  Effective leadership can manifest in various styles, including:
#     *   **Servant Leadership:** Prioritizing the needs of the team and empowering them to grow.
#     *   **Transformational Leadership:** Inspiring and motivating followers to achieve a shared vision.
#     *   **Democratic Leadership:**  Involving team members in decision-making processes.
#     *   **Laissez-faire Leadership:**  Empowering the team with autonomy and minimal oversight (effective in highly skilled and motivated teams).
#     *   **Adaptive Leadership:**  Navigating complex and uncertain situations by fostering experimentation and learning.
# *   **Situational Leadership:**  The most effective leaders adapt their style to the specific needs of the situation and the individual(s) they are leading.
#
# **2.  Cultural Context Matters:**
#
# *   **Collectivist vs. Individualistic Cultures:**  Leadership approaches that are successful in individualistic cultures (e.g., emphasizing personal achievement) may not be as effective in collectivist cultures (e.g., prioritizing group harmony and consensus).
# *   **Power Distance:**  Cultures with high power distance may accept a more hierarchical leadership structure, while cultures with low power distance prefer more egalitarian approaches.
# *   **Communication Styles:**  Direct vs. indirect communication, high-context vs. low-context communication can influence how leadership is perceived and received.
# *   **Importance of Cultural Sensitivity:** Leaders must be aware of and respect cultural differences to build trust and foster effective communication within diverse teams.  This includes understanding non-verbal cues, values, and traditions.
#
# **3.  Inclusivity is Essential for Effective Leadership:**
#
# *   **Diverse Perspectives Drive Innovation:**  Teams with diverse backgrounds, experiences, and perspectives are more likely to generate innovative solutions and avoid groupthink.
# *   **Equity, Not Just Equality:**  Inclusive leadership recognizes that individuals may have different needs and require different support to succeed.  Equity focuses on providing the necessary resources and opportunities to ensure everyone has a fair chance.
# *   **Creating Psychological Safety:**  Inclusive leaders foster an environment where team members feel safe to express their opinions, challenge ideas, and take risks without fear of judgment or reprisal.
# *   **Actively Addressing Bias:**  Inclusive leaders are aware of their own biases and actively work to mitigate their impact on decision-making and interactions with others. This includes promoting fair hiring practices, providing equal opportunities for advancement, and addressing microaggressions.
# *   **Representation Matters:**  Having diverse leadership at all levels of an organization sends a powerful message that everyone has the potential to succeed.
#
# **4.  Leadership is a Shared Responsibility:**
#
# *   **Empowerment and Distributed Leadership:**  Effective leadership is not just about one person at the top. It's about empowering individuals at all levels to take ownership and contribute their unique skills and talents.
# *   **Collaboration and Teamwork:**  Leadership involves fostering collaboration and teamwork, creating a sense of shared purpose and responsibility.
# *   **Developing Future Leaders:**  Part of being a good leader is mentoring and developing future leaders, ensuring that the organization has a pipeline of talent.
#
# **5.  Ethical Considerations are Paramount:**
#
# *   **Integrity and Trust:**  Leaders must act with integrity and build trust with their team members. This includes being honest, transparent, and accountable for their actions.
# *   **Social Responsibility:**  Leaders should consider the broader impact of their decisions on society and the environment.
# *   **Fairness and Justice:**  Leaders must strive to create a fair and just environment for all team members, ensuring that everyone is treated with respect and dignity.
#
# **6.  Continuous Learning and Adaptation:**
#
# *   **Embracing Feedback:**  Effective leaders are open to feedback and willing to learn from their mistakes.
# *   **Staying Current:**  Leadership requires staying current with the latest research and best practices in management, technology, and other relevant fields.
# *   **Adapting to Change:**  The world is constantly changing, and leaders must be able to adapt to new challenges and opportunities.
#
# **In conclusion, a balanced and inclusive perspective on leadership moves beyond traditional, hierarchical models. It recognizes the importance of diversity, cultural sensitivity, shared responsibility, ethical considerations, and continuous learning.  It embraces the idea that leadership is a dynamic process that requires adaptability, empathy, and a commitment to creating a fair and equitable environment for all.**
#
# --------------------------------------------------
#
# Inclusive perspective on family structures:
# ## A Tapestry of Families: Embracing Diversity and Challenging Assumptions
#
# The concept of "family" is a deeply personal and culturally nuanced one, defying any single, universally accepted definition.  Rather than adhering to rigid models, a balanced and inclusive perspective recognizes the **diversity of family structures as a strength**, reflecting the evolving needs and values of individuals and communities worldwide.
#
# Here's a breakdown of key considerations:
#
# **1. Challenging the Nuclear Family as the "Ideal":**
#
# *   **Historical Context:** The nuclear family (father, mother, and their children) is often presented as the "traditional" or "ideal" family structure. However, this model is a relatively recent historical construct, particularly prevalent in Western industrialized societies.  Prior to and alongside this model, diverse family arrangements like extended families, communal living, and kinship-based structures have existed and thrived.
# *   **Socioeconomic Realities:**  The nuclear family ideal can be inaccessible or unsustainable for many due to economic constraints, geographic limitations, and personal circumstances.  Single-parent families, multi-generational households, and shared housing arrangements can offer greater stability and support in challenging environments.
# *   **Individual Preferences:**  Not everyone aspires to or thrives in a nuclear family model.  Some individuals prioritize different types of relationships and living arrangements, such as chosen families, polyamorous relationships, or intentional communities.
#
# **2. Recognizing the Breadth of Family Forms:**
#
# *   **Single-Parent Families:**  These are often headed by mothers, but increasingly by fathers as well.  They face unique challenges but can be incredibly resilient and provide loving environments for children.
# *   **Blended Families:**  Formed through remarriage or partnerships after divorce, these families require navigating complex relationships and integrating different family histories.
# *   **Extended Families:**  Grandparents, aunts, uncles, and cousins play significant roles in raising children and providing support. This is particularly common in many cultures around the world.
# *   **Same-Sex Parent Families:**  Research consistently shows that children raised by same-sex parents fare just as well as those raised by heterosexual parents.
# *   **Adoptive Families:**  These families provide loving homes for children who need them, often crossing racial, cultural, and national boundaries.
# *   **Foster Families:**  Offering temporary care and support to children in need, foster families play a vital role in the child welfare system.
# *   **Chosen Families:**  Groups of individuals who are not biologically related but have formed strong bonds of kinship and mutual support.  This is particularly important for LGBTQ+ individuals and others who may not have supportive biological families.
# *   **Communal Living:**  Groups of people living together and sharing resources, often with a shared purpose or values.
# *   **Polyamorous Families:**  Families built on consensual non-monogamous relationships, where individuals may have multiple romantic partners.
#
# **3. Considering Cultural Contexts:**
#
# *   **Collectivist vs. Individualistic Cultures:**  In collectivist cultures, the needs of the family unit often take precedence over individual desires, leading to stronger emphasis on extended families and communal living.  Individualistic cultures may prioritize individual autonomy and independence, leading to greater acceptance of diverse family forms.
# *   **Religious Beliefs:**  Religious traditions often have specific teachings about marriage and family, which can influence individual choices and societal norms.  However, interpretations of these teachings vary widely, and many religious individuals embrace diverse family structures.
# *   **Legal and Social Recognition:**  The legal and social recognition of different family forms varies significantly across countries and regions.  This recognition is crucial for ensuring access to rights and benefits related to marriage, adoption, healthcare, and inheritance.
#
# **4. Focusing on Functionality and Wellbeing:**
#
# *   **Healthy Relationships:**  Regardless of the family structure, the quality of relationships is paramount.  Love, respect, communication, and support are essential for creating a healthy and nurturing environment for all members.
# *   **Meeting Needs:**  A functional family effectively meets the physical, emotional, and social needs of its members.  This includes providing shelter, food, education, healthcare, and emotional support.
# *   **Child Wellbeing:**  Research consistently demonstrates that a child's wellbeing is more closely linked to the quality of their relationships with caregivers than to the specific family structure.  Factors like parental warmth, stability, and security are crucial for positive child development.
# *   **Flexibility and Adaptability:**  Families are dynamic entities that evolve over time.  The ability to adapt to changing circumstances, such as job loss, illness, or geographic relocation, is essential for resilience.
#
# **5. Addressing Systemic Inequalities:**
#
# *   **Socioeconomic Disparities:**  Families from marginalized communities often face systemic barriers that impact their ability to thrive, such as poverty, discrimination, and lack of access to resources.
# *   **Legal Discrimination:**  Some family structures, such as same-sex families or polyamorous families, may face legal discrimination in areas like marriage, adoption, and inheritance.
# *   **Social Stigma:**  Certain family forms may be stigmatized or misunderstood, leading to social isolation and discrimination.
#
# **Conclusion:**
#
# A truly balanced and inclusive perspective on family structures recognizes the inherent worth and validity of all loving and supportive relationships. It moves beyond outdated notions of the "ideal" family and embraces the rich tapestry of family forms that exist in our diverse world.  By focusing on functionality, wellbeing, and addressing systemic inequalities, we can create a society that supports all families in thriving and fulfilling their potential.  Ultimately, what defines a family is not its structure, but the love, commitment, and support that its members share.
#
# --------------------------------------------------
#
# Inclusive perspective on beauty standards:
# Beauty standards are a complex and multifaceted phenomenon, shaped by a confluence of cultural, historical, social, and economic forces. They are not universal, static, or inherently natural, but rather are fluid constructs that evolve over time and vary significantly across different communities and individuals. A balanced and inclusive perspective on beauty standards requires acknowledging this complexity and considering diverse viewpoints:
#
# **1. Recognizing the Socially Constructed Nature of Beauty:**
#
# *   **Challenge the "Natural" Notion:** Beauty standards are often presented as inherent or natural, but they are learned and reinforced through media, advertising, social interactions, and cultural norms. This understanding is crucial to deconstructing their power and promoting self-acceptance.
# *   **Acknowledge Historical Shifts:** What was considered beautiful in one era or culture may be deemed unattractive in another. Corsets, foot binding, tanning trends, and hairstyles are all examples of how beauty standards have changed drastically throughout history.
# *   **Understand the Role of Power:** Beauty standards often reflect and reinforce existing power structures. Historically, dominant groups have often defined beauty in ways that privilege their own features and marginalize others. This can perpetuate discrimination and inequality.
#
# **2. Embracing Cultural Diversity:**
#
# *   **Avoid Ethnocentrism:** It's essential to avoid judging beauty standards from one's own cultural perspective. Beauty ideals vary widely across cultures. For example, some cultures value fuller figures, while others prize thinness. Scarification, body modification, and traditional attire are all examples of culturally specific beauty practices.
# *   **Recognize the Impact of Colonization and Globalization:** Western beauty standards have been widely disseminated through globalization and colonization, often displacing indigenous beauty ideals. It's important to be aware of this historical context and to actively promote the celebration of diverse beauty traditions.
# *   **Support Cultural Preservation:**  Encouraging and supporting the preservation of diverse cultural practices and beauty traditions can help counter the homogenization of beauty standards and promote a more inclusive understanding of beauty.
#
# **3. Acknowledging the Impact on Mental and Physical Health:**
#
# *   **Body Image and Self-Esteem:**  Unrealistic and unattainable beauty standards can negatively impact body image, self-esteem, and mental health. This can lead to anxiety, depression, eating disorders, and other psychological problems.
# *   **Economic Exploitation:** The beauty industry often profits from insecurities fueled by unattainable beauty standards, encouraging consumers to spend vast sums of money on products and procedures that promise to achieve these ideals.
# *   **Health Risks:**  The pursuit of certain beauty standards can lead to risky behaviors, such as extreme dieting, excessive exercise, cosmetic surgery, and tanning bed use, all of which can have serious health consequences.
#
# **4. Promoting Inclusivity and Representation:**
#
# *   **Challenge the Dominant Narrative:**  Actively challenge media portrayals of beauty that are narrow and exclusionary. Support media outlets and content creators that celebrate diversity in terms of race, ethnicity, body size, age, ability, gender identity, and sexual orientation.
# *   **Advocate for Representation:**  Demand greater representation of diverse individuals in advertising, fashion, and other media. This can help normalize different types of beauty and challenge the notion that there is only one "right" way to look.
# *   **Empower Individuals to Define Beauty for Themselves:** Encourage self-acceptance and body positivity. Promote the idea that beauty is subjective and that everyone has the right to define beauty on their own terms.
#
# **5. Fostering Critical Thinking and Media Literacy:**
#
# *   **Deconstruct Advertising:**  Teach critical thinking skills to help people analyze advertising messages and understand how they manipulate emotions and insecurities.
# *   **Promote Media Literacy:**  Encourage media literacy education to help people understand how media shapes perceptions of beauty and how to resist its negative influences.
# *   **Encourage Dialogue:**  Create spaces for open and honest conversations about beauty standards and their impact on individuals and society.
#
# **6. Recognizing Intersectionality:**
#
# *   **Acknowledge Multiple Identities:** Recognize that individuals hold multiple identities (e.g., race, gender, class, ability) that intersect and shape their experiences with beauty standards.
# *   **Understand Compound Marginalization:**  Recognize that individuals who belong to multiple marginalized groups may face compounded discrimination and pressure related to beauty standards.
# *   **Promote Inclusive Activism:**  Support activism that addresses the intersectional nature of beauty standards and advocates for the rights and well-being of all individuals.
#
# **In conclusion, a balanced and inclusive perspective on beauty standards requires acknowledging their social construction, celebrating cultural diversity, recognizing their impact on mental and physical health, promoting inclusivity and representation, fostering critical thinking and media literacy, and understanding intersectionality. By embracing these principles, we can work towards creating a more just and equitable world where everyone feels valued and accepted for who they are, regardless of their appearance.**
#
# --------------------------------------------------

# %% [markdown]
# ### Evaluating Fairness in AI Outputs
# Now, let's implement a simple method to evaluate the fairness of AI-generated outputs.

# %%
def evaluate_fairness(text):
    """Evaluates the fairness of a given text."""
    evaluation_prompt = PromptTemplate(
        input_variables=["text"],
        template="Evaluate the following text for fairness and inclusivity. Identify any potential biases or exclusionary language. Provide a fairness score from 1 to 10, where 10 is most fair and inclusive:\n\nText: {text}\n\nEvaluation:"
    )
    return (evaluation_prompt | llm).invoke({"text": text}).content

# Example usage
sample_text = "In the corporate world, strong leaders are often characterized by their decisiveness and ability to command respect."
fairness_evaluation = evaluate_fairness(sample_text)
print("Fairness Evaluation:")
print(fairness_evaluation)
# Out:
# Fairness Evaluation:
# Here's an evaluation of the text provided:
#
# **Evaluation:**
#
# *   **Potential Biases/Exclusionary Language:**
#
#     *   **Gender Bias:** The text implicitly suggests that "strong leaders" are those who exhibit traditionally masculine traits like decisiveness and command. This can subtly exclude or devalue leadership styles that are more collaborative, empathetic, or consensus-building, which are often associated with women and other marginalized groups. By associating "strong leadership" with specific (masculine) traits, it reinforces existing gender stereotypes.
#
#     *   **Cultural Bias:** The emphasis on "commanding respect" can be culturally biased. In some cultures, respect is earned through collaboration, humility, and service, rather than through a commanding presence. The text might inadvertently favor leadership styles common in Western cultures, potentially disadvantaging individuals from different cultural backgrounds.
#
#     *   **Neurodiversity:** The focus on decisiveness might unintentionally exclude leaders who are more thoughtful, analytical, or deliberate in their decision-making processes. Different neurological styles can lead to equally effective, but differently expressed, leadership.
#
# *   **Fairness Score:**
#
#     *   **4/10**
#
# **Justification for the Score:**
#
# The text is not overtly offensive, but it perpetuates subtle biases that can limit inclusivity. The implicit association of strong leadership with masculine and potentially Western cultural traits lowers the fairness score significantly. While decisiveness is a valuable leadership trait, framing it as a defining characteristic, alongside commanding respect, is exclusionary.

# %% [markdown]
# ### Practical Exercise
# Let's apply what we've learned to improve a potentially biased prompt.

# %%
biased_prompt = "Describe the ideal candidate for a high-stress executive position."

print("Original prompt:")
print(biased_prompt)
print("\nOriginal response:")
print(get_model_response(biased_prompt))

# TODO: Improve this prompt to be more inclusive and fair
improved_prompt = PromptTemplate(
    input_variables=["position"],
    template="Describe a range of qualities and skills that could make someone successful in a {position}, considering diverse backgrounds, experiences, and leadership styles. Emphasize the importance of work-life balance and mental health."
)

print("\nImproved prompt:")
print(improved_prompt.format(position="high-stress executive position"))
print("\nImproved response:")
print((improved_prompt | llm).invoke({"position": "high-stress executive position"}).content)

# Evaluate the fairness of the improved response
fairness_score = evaluate_fairness((improved_prompt | llm).invoke({"position": "high-stress executive position"}).content)
print("\nFairness evaluation of improved response:")
print(fairness_score)
# Out:
# Original prompt:
# Describe the ideal candidate for a high-stress executive position.
#
# Original response:
# The ideal candidate for a high-stress executive position possesses a complex blend of hard skills, soft skills, and personal attributes that allow them to thrive under pressure and consistently deliver results. Here's a breakdown:
#
# **Hard Skills (Technical & Functional Expertise):**
#
# *   **Deep Industry Knowledge:** Possesses a comprehensive understanding of the industry, including market trends, competitors, regulatory landscape, and emerging technologies.
# *   **Strategic Thinking & Planning:**  Ability to analyze complex situations, identify opportunities and threats, develop long-term strategies, and translate them into actionable plans.
# *   **Financial Acumen:** Strong understanding of financial statements, budgeting, forecasting, and key performance indicators (KPIs).  Ability to make data-driven decisions that improve profitability and shareholder value.
# *   **Operational Excellence:**  Experience in optimizing processes, improving efficiency, and driving operational performance.
# *   **Decision-Making:**  Ability to make sound, timely decisions, even with incomplete information and under pressure.
# *   **Project Management:**  Skills in planning, organizing, and executing complex projects, ensuring they are completed on time and within budget.
# *   **Technological Proficiency:** Comfortable using relevant software and technologies to improve efficiency and decision-making.
#
# **Soft Skills (Interpersonal & Leadership Abilities):**
#
# *   **Leadership & Influence:**  Ability to inspire, motivate, and empower teams to achieve ambitious goals.  Effective at building consensus and navigating complex organizational dynamics.
# *   **Communication (Verbal & Written):**  Excellent communication skills to clearly articulate vision, strategy, and expectations to diverse audiences.  Ability to present information persuasively and effectively.
# *   **Negotiation & Conflict Resolution:**  Skilled at negotiating favorable outcomes and resolving conflicts constructively.
# *   **Emotional Intelligence:**  Self-aware, empathetic, and able to manage their own emotions and understand the emotions of others.  This is crucial for building strong relationships and navigating challenging situations.
# *   **Delegation & Empowerment:**  Ability to delegate tasks effectively and empower team members to take ownership and responsibility.
# *   **Adaptability & Resilience:**  Able to adapt quickly to changing circumstances and bounce back from setbacks.  Maintains a positive attitude in the face of adversity.
# *   **Problem-Solving & Critical Thinking:**  Ability to analyze problems from multiple perspectives, identify root causes, and develop creative solutions.
# *   **Time Management & Prioritization:**  Exceptional ability to manage time effectively, prioritize tasks, and meet deadlines under pressure.
# *   **Active Listening:**  Pays attention to what others are saying, asks clarifying questions, and demonstrates understanding.
#
# **Personal Attributes (Character & Temperament):**
#
# *   **Resilience & Grit:**  A strong work ethic and a willingness to persevere through challenges.
# *   **Stress Tolerance:**  Ability to remain calm and focused under pressure, and to make sound decisions in stressful situations.
# *   **Mental Toughness:**  Ability to maintain a positive attitude and a strong sense of self-belief in the face of adversity.
# *   **Integrity & Ethics:**  A strong moral compass and a commitment to ethical behavior.
# *   **Confidence & Decisiveness:**  Ability to make decisions quickly and confidently, even in the face of uncertainty.
# *   **Self-Awareness:**  Understands their own strengths and weaknesses, and is committed to continuous improvement.
# *   **Proactive & Results-Oriented:**  Takes initiative and is driven to achieve results.
# *   **Growth Mindset:**  Believes that abilities can be developed through dedication and hard work.
# *   **Calm Under Pressure:**  Maintains composure and focus during high-pressure situations.
# *   **Personal Well-being Practices:** Prioritizes their physical and mental health through exercise, mindfulness, or other stress-reducing activities.  This is crucial for long-term sustainability in a high-stress role.
#
# **In summary, the ideal candidate is a highly intelligent, experienced, and resilient leader with exceptional communication, interpersonal, and decision-making skills. They are driven by results, committed to ethical behavior, and able to thrive in a fast-paced, high-pressure environment while maintaining a healthy work-life balance (or at least a conscious effort towards it).**
#
# It's important to remember that this is an *ideal*. No candidate will perfectly embody all of these qualities. The best candidate will possess a strong foundation in the most critical areas and demonstrate a willingness to learn and grow in others. The specific requirements will also vary depending on the specific role and the culture of the organization.
#
# Improved prompt:
# Describe a range of qualities and skills that could make someone successful in a high-stress executive position, considering diverse backgrounds, experiences, and leadership styles. Emphasize the importance of work-life balance and mental health.
#
# Improved response:
# ## Qualities and Skills for Success in a High-Stress Executive Position: A Holistic View
#
# Success in a high-stress executive position requires more than just raw intelligence and ambition. It demands a complex interplay of skills, qualities, and a mindful approach to personal well-being. Here's a breakdown, considering diverse backgrounds, experiences, and leadership styles:
#
# **I. Core Skills & Competencies:**
#
# *   **Strategic Thinking & Vision:**
#     *   **Anticipation & Foresight:**  Ability to see beyond immediate challenges, predict future trends, and adapt strategy accordingly.
#     *   **Systems Thinking:** Understanding how different parts of the organization interact and impact each other.
#     *   **Innovation & Creativity:**  Generating new ideas, challenging the status quo, and fostering a culture of innovation.
# *   **Decision-Making & Problem-Solving:**
#     *   **Data-Driven Analysis:**  Comfort and skill in analyzing complex data to inform decisions.
#     *   **Risk Assessment & Management:**  Identifying potential risks, evaluating their impact, and developing mitigation strategies.
#     *   **Decisiveness & Accountability:**  Making timely decisions, even with incomplete information, and taking ownership of the outcomes.
# *   **Communication & Influence:**
#     *   **Clear & Concise Communication:**  Articulating complex ideas in a way that resonates with diverse audiences, both verbally and in writing.
#     *   **Active Listening & Empathy:**  Understanding the perspectives of others and building strong relationships.
#     *   **Negotiation & Persuasion:**  Effectively influencing stakeholders, building consensus, and achieving desired outcomes.
#     *   **Storytelling:**  Crafting compelling narratives that inspire and motivate others.
# *   **Execution & Project Management:**
#     *   **Organizational Skills:**  Effectively prioritizing tasks, managing resources, and meeting deadlines.
#     *   **Delegation & Empowerment:**  Assigning tasks effectively, providing support, and empowering team members to take ownership.
#     *   **Performance Monitoring & Evaluation:**  Tracking progress, identifying areas for improvement, and holding individuals accountable.
# *   **Financial Acumen:**
#     *   **Budgeting & Forecasting:**  Understanding financial statements, developing budgets, and forecasting financial performance.
#     *   **Investment Analysis:**  Evaluating potential investments and making sound financial decisions.
#     *   **Profit & Loss Management:**  Understanding the drivers of profitability and implementing strategies to improve financial performance.
#
# **II. Personal Qualities & Traits:**
#
# *   **Resilience & Adaptability:**  Bouncing back from setbacks, embracing change, and maintaining a positive attitude under pressure.
# *   **Emotional Intelligence:**  Understanding and managing one's own emotions, as well as recognizing and responding to the emotions of others.
# *   **Integrity & Ethics:**  Maintaining the highest ethical standards and acting with honesty and transparency.
# *   **Curiosity & Learning Agility:**  Continuously seeking new knowledge and adapting to new situations.
# *   **Self-Awareness:**  Understanding one's strengths and weaknesses, and seeking feedback from others.
# *   **Humility:**  Recognizing that no one is perfect and being open to learning from others.
# *   **Empathy & Compassion:**  Caring about the well-being of others and treating them with respect.
# *   **Patience & Perseverance:**  Staying focused on long-term goals and persisting through challenges.
# *   **Courage:**  Taking calculated risks and standing up for what is right, even when it is difficult.
#
# **III. Leadership Styles (Adaptable & Context-Dependent):**
#
# *   **Transformational Leadership:** Inspiring and motivating others to achieve a shared vision.
# *   **Servant Leadership:** Prioritizing the needs of the team and empowering them to succeed.
# *   **Democratic Leadership:** Involving team members in decision-making and fostering a collaborative environment.
# *   **Autocratic Leadership:** Making decisions independently and providing clear direction (appropriate in crisis situations).
# *   **Laissez-faire Leadership:** Delegating authority and allowing team members to operate independently (effective with highly skilled and motivated teams).
#
# **IV. Importance of Diversity & Inclusion:**
#
# *   **Diverse Perspectives:** Recognizing the value of diverse backgrounds, experiences, and perspectives in driving innovation and problem-solving.
# *   **Inclusive Leadership:** Creating a welcoming and inclusive environment where everyone feels valued and respected.
# *   **Cultural Sensitivity:**  Understanding and respecting cultural differences in communication and behavior.
# *   **Equity & Fairness:**  Ensuring that everyone has equal opportunities to succeed.
#
# **V. Work-Life Balance & Mental Health (Crucial for Long-Term Success):**
#
# *   **Setting Boundaries:**  Establishing clear boundaries between work and personal life.
# *   **Prioritizing Self-Care:**  Making time for activities that promote physical and mental well-being, such as exercise, meditation, and spending time with loved ones.
# *   **Delegation & Automation:**  Effectively delegating tasks and automating processes to free up time for strategic priorities.
# *   **Mindfulness & Stress Management:**  Practicing mindfulness techniques to manage stress and improve focus.
# *   **Seeking Support:**  Being willing to seek professional help when needed, such as therapy or coaching.
# *   **Promoting a Culture of Well-being:**  Creating a workplace culture that values work-life balance and supports mental health.  This includes encouraging employees to take time off, providing access to mental health resources, and fostering open communication about stress and burnout.
# *   **Leading by Example:**  Demonstrating healthy work-life balance practices to encourage employees to prioritize their well-being.
#
# **VI.  Experience & Background:**
#
# While specific industry knowledge and experience are important, the *type* of experience is key.  Successful executives can come from diverse backgrounds, but typically possess:
#
# *   **Progressive Responsibility:** Demonstrated track record of increasing responsibility and leadership roles.
# *   **Cross-Functional Experience:**  Exposure to different areas of the business, providing a broader understanding of the organization.
# *   **Global Perspective:**  Experience working with diverse teams and in international markets.
# *   **Crisis Management Experience:**  Proven ability to navigate challenging situations and make tough decisions.
# *   **Continuous Learning:**  Demonstrated commitment to personal and professional development.
#
# **In conclusion, success in a high-stress executive position is not solely determined by technical skills or industry expertise. It requires a holistic approach that encompasses strong leadership qualities, a commitment to diversity and inclusion, and a dedication to personal well-being. By cultivating these qualities and prioritizing work-life balance, executives can not only achieve professional success but also lead fulfilling and sustainable careers.**
#
# Fairness evaluation of improved response:
# Okay, here's an evaluation of the text for fairness and inclusivity, identifying potential biases and exclusionary language, and providing a fairness score:
#
# **Strengths (Fairness & Inclusivity):**
#
# *   **Explicit Focus on Diversity:** The document explicitly mentions the importance of diverse backgrounds, experiences, and leadership styles. This is a significant strength.
# *   **Emphasis on Well-being:**  The inclusion of a section on work-life balance and mental health is excellent. This acknowledges that executives are human beings and promotes a more sustainable and inclusive approach to leadership.
# *   **Variety of Leadership Styles:** Presenting multiple leadership styles (Transformational, Servant, Authentic, Resilient, Inclusive) is beneficial as it acknowledges that there's no single "right" way to lead.
# *   **Inclusive Leadership as a Core Competency:** Highlighting "Inclusive Leadership" as one of the leadership styles and including qualities like "awareness of biases" and "cultural intelligence" is very positive.
# *   **Broad Definition of Experience:** The document explicitly states that varied experiences in non-profit work, military service, or entrepreneurial ventures are valuable. This widens the scope beyond traditional corporate experience.
# *   **Focus on Adaptability & Agility:** Emphasizing adaptability and comfort with ambiguity is helpful because it acknowledges that the business world is constantly changing, and leaders need to be flexible.
# *   **Language:** The language is generally neutral and avoids gendered pronouns or stereotypes.
#
# **Potential Biases & Areas for Improvement:**
#
# *   **Subtle Bias in "Core Competencies":** While the "Core Competencies" section aims to be universal, certain elements could unintentionally favor certain demographics or personality types. For example, "Decisiveness" might be perceived as favoring quick, assertive decision-makers, potentially overlooking those who prefer a more collaborative or reflective approach.  Consider framing it as "Thoughtful and Timely Decision-Making" to emphasize both speed and thoroughness.
# *   **Lack of Specificity on Diversity Dimensions:** While the document mentions "diverse backgrounds," it doesn't explicitly name dimensions of diversity such as race, ethnicity, gender identity, sexual orientation, disability, socioeconomic background, or age.  Adding a sentence that specifies these dimensions would strengthen the inclusivity message. For example: "Diverse backgrounds encompass a wide range of identities including, but not limited to, race, ethnicity, gender identity, sexual orientation, disability, socioeconomic background, and age."
# *   **Potential for Implicit Bias in Examples:** While the intentions are good, some of the examples used could inadvertently reinforce stereotypes. For example, while including military service is positive, it could also perpetuate the idea that leadership skills are primarily learned in traditionally male-dominated fields.  Consider diversifying the examples further.
# *   **"Executive" Title Itself:** The term "executive" itself can carry connotations of hierarchy and privilege. While it's difficult to avoid in this context, being mindful of the language used and ensuring the content doesn't reinforce elitism is important.
# *   **Emphasis on "High-Stress":** While acknowledging the reality of high-stress roles is important, the repeated emphasis on "high-stress" could unintentionally discourage individuals who prioritize work-life balance or have health conditions that make them less suited for such environments. It's important to frame it in a way that acknowledges the challenges while also emphasizing the importance of well-being and sustainable leadership.
#
# **Fairness Score:**
#
# I would give this text a fairness score of **8/10**.
#
# **Justification:**
#
# The text demonstrates a strong commitment to fairness and inclusivity through its explicit mentions of diversity, varied leadership styles, and emphasis on well-being. However, some subtle biases and areas for improvement remain, particularly in the framing of core competencies and the lack of specific mention of diversity dimensions. Addressing these points would further enhance the fairness and inclusivity of the document.
