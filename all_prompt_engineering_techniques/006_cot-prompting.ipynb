# %% [markdown]
# # Chain of Thought (CoT) Prompting Tutorial
# ### Overview
# This tutorial introduces Chain of Thought (CoT) prompting, a powerful technique in prompt engineering that encourages AI models to break down complex problems into step-by-step reasoning processes. We'll explore how to implement CoT prompting using OpenAI's GPT models and the LangChain library.
#
# ### Motivation
# As AI language models become more advanced, there's an increasing need to guide them towards producing more transparent, logical, and verifiable outputs. CoT prompting addresses this need by encouraging models to show their work, much like how humans approach complex problem-solving tasks. This technique not only improves the accuracy of AI responses but also makes them more interpretable and trustworthy.
#
# ### Key Components
# 1. Basic CoT Prompting: Introduction to the concept and simple implementation.
# 2. Advanced CoT Techniques: Exploring more sophisticated CoT approaches.
# 3. Comparative Analysis: Examining the differences between standard and CoT prompting.
# 4. Problem-Solving Applications: Applying CoT to various complex tasks.
# ### Method Details
# The tutorial will guide learners through the following methods:
#
# 1. Setting up the environment: We'll start by importing necessary libraries and setting up the OpenAI API.
#
# 2. Basic CoT Implementation: We'll create simple CoT prompts and compare their outputs to standard prompts.
#
# 3. Advanced CoT Techniques: We'll explore more complex CoT strategies, including multi-step reasoning and self-consistency checks.
#
# 4. Practical Applications: We'll apply CoT prompting to various problem-solving scenarios, such as mathematical word problems and logical reasoning tasks.
#
# ### Conclusion
# By the end of this tutorial, learners will have a solid understanding of Chain of Thought prompting and its applications. They will be equipped with practical skills to implement CoT techniques in various scenarios, improving the quality and interpretability of AI-generated responses. This knowledge will be valuable for anyone working with large language models, from developers and researchers to business analysts and decision-makers relying on AI-powered insights.
#
# ### Setup
# Let's start by importing the necessary libraries and setting up our environment.

# %%
import os
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# Load enviroment variables
from dotenv import load_dotenv
load_dotenv()

# Set up Google API key
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# Initialize the language model
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %% [markdown]
# ### Basic Chain of Thought Prompting
# Let's start with a simple example to demonstrate the difference between a standard prompt and a Chain of Thought prompt.

# %%
# Standard prompt
standard_prompt = PromptTemplate(
    input_variables=["question"],
    template="Answer the following question concisely: {question}."
)

# Chain of Thought prompt
cot_prompt = PromptTemplate(
    input_variables=["question"],
    template="Answer the following question step by step concisely: {question}"
)

# Create chains
standard_chain = standard_prompt | llm
cot_chain = cot_prompt | llm

# Example question
question = "If a train travels 120 km in 2 hours, what is its average speed in km/h?"

# Get responses
standard_response = standard_chain.invoke(question).content
cot_response = cot_chain.invoke(question).content

print("Standard Response:")
print(standard_response)
print("\nChain of Thought Response:")
print(cot_response)
# Out:
# Standard Response:
# 60 km/h
#
# Chain of Thought Response:
# 1. **Average speed formula:** Average speed = Total distance / Total time
# 2. **Plug in the values:** Average speed = 120 km / 2 hours
# 3. **Calculate:** Average speed = 60 km/h

# %% [markdown]
# ### Advanced Chain of Thought Techniques
# Now, let's explore a more advanced CoT technique that encourages multi-step reasoning.

# %%
advanced_cot_prompt = PromptTemplate(
    input_variables=["question"],
    template="""Solve the following problem step by step. For each step:
1. State what you're going to calculate
2. Write the formula you'll use (if applicable)
3. Perform the calculation
4. Explain the result

Question: {question}

Solution:"""
)

advanced_cot_chain = advanced_cot_prompt | llm

complex_question = "A car travels 150 km at 60 km/h, then another 100 km at 50 km/h. What is the average speed for the entire journey?"

advanced_cot_response = advanced_cot_chain.invoke(complex_question).content
print(advanced_cot_response)
# Out:
# Okay, let's solve this problem step-by-step.
#
# **Step 1: Calculate the time taken for the first part of the journey.**
#
# 1.  **What:** We need to find the time it took to travel the first 150 km.
# 2.  **Formula:**  Time = Distance / Speed
# 3.  **Calculation:** Time = 150 km / 60 km/h = 2.5 hours
# 4.  **Result:** The car took 2.5 hours to travel the first 150 km.
#
# **Step 2: Calculate the time taken for the second part of the journey.**
#
# 1.  **What:** We need to find the time it took to travel the next 100 km.
# 2.  **Formula:** Time = Distance / Speed
# 3.  **Calculation:** Time = 100 km / 50 km/h = 2 hours
# 4.  **Result:** The car took 2 hours to travel the next 100 km.
#
# **Step 3: Calculate the total distance traveled.**
#
# 1.  **What:** We need to find the total distance the car traveled.
# 2.  **Formula:** Total Distance = Distance 1 + Distance 2
# 3.  **Calculation:** Total Distance = 150 km + 100 km = 250 km
# 4.  **Result:** The car traveled a total of 250 km.
#
# **Step 4: Calculate the total time taken for the entire journey.**
#
# 1.  **What:** We need to find the total time the car was traveling.
# 2.  **Formula:** Total Time = Time 1 + Time 2
# 3.  **Calculation:** Total Time = 2.5 hours + 2 hours = 4.5 hours
# 4.  **Result:** The car traveled for a total of 4.5 hours.
#
# **Step 5: Calculate the average speed for the entire journey.**
#
# 1.  **What:** We need to find the average speed for the whole trip.
# 2.  **Formula:** Average Speed = Total Distance / Total Time
# 3.  **Calculation:** Average Speed = 250 km / 4.5 hours = 55.56 km/h (approximately)
# 4.  **Result:** The average speed for the entire journey is approximately 55.56 km/h.
#
# **Final Answer:** The average speed for the entire journey is approximately 55.56 km/h.

# %% [markdown]
# ### Comparative Analysis
# Let's compare the effectiveness of standard prompting vs. CoT prompting on a more challenging problem.

# %%
challenging_question = """
A cylindrical water tank with a radius of 1.5 meters and a height of 4 meters is 2/3 full. 
If water is being added at a rate of 10 liters per minute, how long will it take for the tank to overflow? 
Give your answer in hours and minutes, rounded to the nearest minute. 
(Use 3.14159 for π and 1000 liters = 1 cubic meter)"""

standard_response = standard_chain.invoke(challenging_question).content
cot_response = advanced_cot_chain.invoke(challenging_question).content

print("Standard Response:")
print(standard_response)
print("\nChain of Thought Response:")
print(cot_response)
# Out:
# Standard Response:
# It will take approximately **4 hours and 43 minutes** for the tank to overflow.
#
# Chain of Thought Response:
# Okay, let's solve this problem step-by-step.
#
# **Step 1: Calculate the total volume of the cylindrical tank.**
#
# 1.  **What:** We need to find the total volume the tank can hold.
# 2.  **Formula:** The volume of a cylinder is given by  V = πr²h, where r is the radius and h is the height.
# 3.  **Calculation:**
#     V = πr²h = 3.14159 * (1.5 m)² * 4 m
#     V = 3.14159 * 2.25 m² * 4 m
#     V = 28.27431 m³
# 4.  **Result:** The total volume of the tank is approximately 28.27431 cubic meters.
#
# **Step 2: Calculate the current volume of water in the tank.**
#
# 1.  **What:** We need to determine how much water is currently in the tank.
# 2.  **Formula:** The tank is 2/3 full, so the current volume is (2/3) * Total Volume.
# 3.  **Calculation:**
#     Current Volume = (2/3) * 28.27431 m³
#     Current Volume ≈ 18.84954 m³
# 4.  **Result:** The tank currently contains approximately 18.84954 cubic meters of water.
#
# **Step 3: Calculate the remaining volume needed to fill the tank.**
#
# 1.  **What:** We need to find the difference between the total volume and the current volume.
# 2.  **Formula:**  Remaining Volume = Total Volume - Current Volume
# 3.  **Calculation:**
#     Remaining Volume = 28.27431 m³ - 18.84954 m³
#     Remaining Volume ≈ 9.42477 m³
# 4.  **Result:**  Approximately 9.42477 cubic meters of water are needed to fill the tank.
#
# **Step 4: Convert the remaining volume to liters.**
#
# 1.  **What:** We need to express the remaining volume in liters, as the water flow rate is given in liters per minute.
# 2.  **Formula:** 1 m³ = 1000 liters
# 3.  **Calculation:**
#     Remaining Volume (liters) = 9.42477 m³ * 1000 liters/m³
#     Remaining Volume (liters) ≈ 9424.77 liters
# 4.  **Result:**  Approximately 9424.77 liters of water are needed to fill the tank.
#
# **Step 5: Calculate the time it takes to fill the remaining volume in minutes.**
#
# 1.  **What:** We need to find out how many minutes it will take to add the remaining liters of water, given the flow rate.
# 2.  **Formula:** Time (minutes) = Remaining Volume (liters) / Flow Rate (liters/minute)
# 3.  **Calculation:**
#     Time (minutes) = 9424.77 liters / 10 liters/minute
#     Time (minutes) ≈ 942.477 minutes
# 4.  **Result:** It will take approximately 942.477 minutes to fill the remaining volume.
#
# **Step 6: Convert the time from minutes to hours and minutes.**
#
# 1.  **What:** We need to express the time in a more understandable format (hours and minutes).
# 2.  **Formula:**
#     *   Hours = Total Minutes / 60
#     *   Remaining Minutes = Total Minutes % 60  (where % is the modulo operator, giving the remainder of the division)
# 3.  **Calculation:**
#     Hours = 942.477 minutes / 60 minutes/hour ≈ 15.70795 hours
#     Hours = 15 (integer part)
#     Remaining Minutes = 942.477 minutes % 60 minutes/hour ≈ 42.477 minutes
#     Remaining Minutes = 42 (rounded to nearest minute)
# 4.  **Result:** It will take approximately 15 hours and 42 minutes to fill the tank.
#
# **Final Answer:**
#
# It will take approximately **15 hours and 42 minutes** for the tank to overflow.

# %% [markdown]
# ### Problem-Solving Applications
# Now, let's apply CoT prompting to a more complex logical reasoning task.

# %%
logical_reasoning_prompt = PromptTemplate(
    input_variables=["scenario"],
    template="""Analyze the following logical puzzle thoroughly. Follow these steps in your analysis:

List the Facts:

Summarize all the given information and statements clearly.
Identify all the characters or elements involved.
Identify Possible Roles or Conditions:

Determine all possible roles, behaviors, or states applicable to the characters or elements (e.g., truth-teller, liar, alternator).
Note the Constraints:

Outline any rules, constraints, or relationships specified in the puzzle.
Generate Possible Scenarios:

Systematically consider all possible combinations of roles or conditions for the characters or elements.
Ensure that all permutations are accounted for.
Test Each Scenario:

For each possible scenario:
Assume the roles or conditions you've assigned.
Analyze each statement based on these assumptions.
Check for consistency or contradictions within the scenario.
Eliminate Inconsistent Scenarios:

Discard any scenarios that lead to contradictions or violate the constraints.
Keep track of the reasoning for eliminating each scenario.
Conclude the Solution:

Identify the scenario(s) that remain consistent after testing.
Summarize the findings.
Provide a Clear Answer:

State definitively the role or condition of each character or element.
Explain why this is the only possible solution based on your analysis.
Scenario:

{scenario}

Analysis:""")

logical_reasoning_chain = logical_reasoning_prompt | llm

logical_puzzle = """In a room, there are three people: Amy, Bob, and Charlie. 
One of them always tells the truth, one always lies, and one alternates between truth and lies. 
Amy says, 'Bob is a liar.' 
Bob says, 'Charlie alternates between truth and lies.' 
Charlie says, 'Amy and I are both liars.' 
Determine the nature (truth-teller, liar, or alternator) of each person."""

logical_reasoning_response = logical_reasoning_chain.invoke(logical_puzzle).content
print(logical_reasoning_response)
# Out:
# Okay, let's break down this classic logic puzzle step-by-step.
#
# **1. List the Facts:**
#
# *   **Characters:** Amy, Bob, Charlie
# *   **Roles:** Truth-teller, Liar, Alternator (Truth/Lie)
# *   **Statements:**
#     *   Amy: "Bob is a liar."
#     *   Bob: "Charlie alternates between truth and lies."
#     *   Charlie: "Amy and I are both liars."
# *   **Constraints:**
#     *   Each person has exactly one role.
#     *   There is one truth-teller, one liar, and one alternator.
#
# **2. Identify Possible Roles or Conditions:**
#
# The possible roles are Truth-teller (T), Liar (L), and Alternator (A).
#
# **3. Note the Constraints:**
#
# *   One person is the truth-teller.
# *   One person is the liar.
# *   One person is the alternator.
# *   The alternator *must* alternate between truth and lies, meaning their statements cannot be consistently true or consistently false.
#
# **4. Generate Possible Scenarios:**
#
# We need to consider all possible assignments of roles to Amy, Bob, and Charlie. There are 3! (3 factorial) = 3 * 2 * 1 = 6 possible scenarios:
#
# 1.  Amy (T), Bob (L), Charlie (A)
# 2.  Amy (T), Bob (A), Charlie (L)
# 3.  Amy (L), Bob (T), Charlie (A)
# 4.  Amy (L), Bob (A), Charlie (T)
# 5.  Amy (A), Bob (T), Charlie (L)
# 6.  Amy (A), Bob (L), Charlie (T)
#
# **5. Test Each Scenario:**
#
# Let's meticulously examine each scenario, evaluating the truthfulness of each statement based on the assigned roles.
#
# **Scenario 1: Amy (T), Bob (L), Charlie (A)**
#
# *   Amy (T): "Bob is a liar."  This statement is TRUE (because Bob is assigned the role of Liar). This is consistent with Amy being the truth-teller.
# *   Bob (L): "Charlie alternates between truth and lies." This statement is FALSE (because Bob is assigned the role of Liar). Therefore, Charlie *cannot* alternate. However, we have assigned Charlie to be the alternator. Thus, the statement must alternate. This scenario is inconsistent.
#
# **Scenario 2: Amy (T), Bob (A), Charlie (L)**
#
# *   Amy (T): "Bob is a liar." This statement is FALSE (because Bob is assigned the role of the alternator). This is inconsistent.
#
# **Scenario 3: Amy (L), Bob (T), Charlie (A)**
#
# *   Amy (L): "Bob is a liar." This statement is FALSE (because Bob is assigned the role of Truth-teller). This is consistent with Amy being the liar.
# *   Bob (T): "Charlie alternates between truth and lies." This statement is TRUE (because Bob is assigned the role of Truth-teller). This is consistent.
# *   Charlie (A): "Amy and I are both liars." If this statement is true, then both Amy and Charlie are liars. If this statement is false, then at least one of them is not a liar. Since Charlie is the alternator, his statement must alternate.
#     * If Charlie's statement is true, then Amy and Charlie are liars. However, we have already assigned Amy as a liar and Charlie as the alternator. So this part works.
#     * If Charlie's statement is false, then at least one of them is not a liar. This is also consistent with the assignments.
#     * This scenario is consistent.
#
# **Scenario 4: Amy (L), Bob (A), Charlie (T)**
#
# *   Amy (L): "Bob is a liar." This statement is FALSE (because Bob is assigned the role of alternator). This is consistent with Amy being the liar.
# *   Bob (A): "Charlie alternates between truth and lies." Charlie is the truth-teller, so this statement is false. If Bob's statement is false, then Charlie does not alternate. This is consistent with Charlie being the Truth-teller. Since Bob is the alternator, his statement must alternate.
#     * If Bob tells the truth, then Charlie is the alternator, which is false.
#     * If Bob lies, then Charlie is not the alternator, which is true.
# *   Charlie (T): "Amy and I are both liars." This statement is FALSE (because Charlie is assigned the role of Truth-teller). This implies that at least one of them is not a liar. However, we have already assigned Amy to be a liar and Charlie as the truth-teller, so this statement is false. The statement is consistent with Charlie being the truth-teller.
# * So the first statement by Bob is false. Therefore, Charlie cannot be the alternator. Since Charlie is the truth-teller, this is consistent. This scenario is consistent.
#
# **Scenario 5: Amy (A), Bob (T), Charlie (L)**
#
# *   Amy (A): "Bob is a liar." Bob is the truth-teller, so this statement is false. Since Amy is the alternator, this statement must alternate.
#     * If Amy tells the truth, then Bob is a liar, which is false.
#     * If Amy lies, then Bob is not a liar, which is true.
# *   Bob (T): "Charlie alternates between truth and lies." This statement is FALSE (because Charlie is a liar). This is inconsistent.
# *   Charlie (L): "Amy and I are both liars." This statement is FALSE (because Charlie is assigned the role of Liar). Since Amy is the alternator, she is not a liar, so this statement is false. This scenario is inconsistent.
#
# **Scenario 6: Amy (A), Bob (L), Charlie (T)**
#
# *   Amy (A): "Bob is a liar." Bob is assigned the role of Liar, so this statement is TRUE. Since Amy is the alternator, this statement must alternate.
#     * If Amy tells the truth, then Bob is a liar, which is true.
#     * If Amy lies, then Bob is not a liar, which is false.
# *   Bob (L): "Charlie alternates between truth and lies." This statement is FALSE (because Charlie is assigned the role of Truth-teller). This is consistent with Bob being the liar.
# *   Charlie (T): "Amy and I are both liars." This statement is FALSE (because Charlie is assigned the role of Truth-teller). Since Amy is the alternator, she cannot be a liar, so the statement is false. This scenario is inconsistent.
#
# **6. Eliminate Inconsistent Scenarios:**
#
# *   Scenario 1: Contradiction with Bob and Charlie.
# *   Scenario 2: Contradiction with Amy.
# *   Scenario 5: Contradiction with Bob and Charlie.
# *   Scenario 6: Contradiction with Charlie.
#
# **7. Conclude the Solution:**
#
# We have two remaining scenarios:
#
# *   Scenario 3: Amy (L), Bob (T), Charlie (A)
# *   Scenario 4: Amy (L), Bob (A), Charlie (T)
#
# We will test these scenarios again:
#
# **Scenario 3: Amy (L), Bob (T), Charlie (A)**
#
# *   Amy (L): "Bob is a liar." False. Consistent.
# *   Bob (T): "Charlie alternates between truth and lies." True. Consistent.
# *   Charlie (A): "Amy and I are both liars."
#     *   If true, then Amy and Charlie are liars. Consistent.
#     *   If false, then Amy or Charlie is not a liar. Consistent.
#
# **Scenario 4: Amy (L), Bob (A), Charlie (T)**
#
# *   Amy (L): "Bob is a liar." False. Consistent.
# *   Bob (A): "Charlie alternates between truth and lies." False. Charlie is the truth-teller, so he doesn't alternate. Consistent.
# *   Charlie (T): "Amy and I are both liars." False. Amy is the liar, and Charlie is the truth-teller. Consistent.
#
# Now, let's look at the alternator statement again.
#
# In Scenario 3: Charlie alternates. So he says, "Amy and I are both liars." This is FALSE. So the next statement he makes would be true.
# In Scenario 4: Bob alternates. So he says, "Charlie alternates between truth and lies." This is FALSE. So the next statement he makes would be true.
#
# Let's assume that each of the people make another statement.
#
# Scenario 3:
# * Amy (L): "Bob is a liar." False.
# * Bob (T): "Charlie alternates between truth and lies." True.
# * Charlie (A): "Amy and I are both liars." False.
# * Amy (L): "I am the alternator." False.
# * Bob (T): "Amy is the liar." True.
# * Charlie (A): "Amy and I are both liars." True.
#
# Scenario 4:
# * Amy (L): "Bob is a liar." False.
# * Bob (A): "Charlie alternates between truth and lies." False.
# * Charlie (T): "Amy and I are both liars." False.
# * Amy (L): "I am the alternator." False.
# * Bob (A): "Charlie alternates between truth and lies." True.
# * Charlie (T): "I am the liar." False.
#
# **8. Provide a Clear Answer:**
#
# *   **Scenario 3 is the only consistent solution.**
#
# *   **Amy is the Liar.**
# *   **Bob is the Truth-teller.**
# *   **Charlie is the Alternator.**
