# %% [markdown]
# # Role Prompting Tutorial
# ### Overview
# This tutorial explores the concept of role prompting in AI language models, focusing on how to assign specific roles to AI models and craft effective role descriptions. We'll use Gemini model and the LangChain library to demonstrate these techniques.
#
# ### Motivation
# Role prompting is a powerful technique in prompt engineering that allows us to guide AI models to adopt specific personas or expertise. This approach can significantly enhance the quality and relevance of AI-generated responses, making them more suitable for specific tasks or domains.
#
# ### Key Components
# 1. Role Assignment: Techniques for assigning roles to AI models
# 2. Role Description Crafting: Strategies for creating effective and detailed role descriptions
# 3. Context Setting: Methods to provide necessary background information for the role
# 4. Task Specification: Approaches to clearly define tasks within the assigned role
# ### Method Details
# Our approach involves the following steps:
#
# 1. Setting up the environment with necessary libraries (Gemini, LangChain)
# 2. Creating role-based prompts using LangChain's PromptTemplate
# 3. Assigning roles to the AI model through carefully crafted prompts
# 4. Demonstrating how different roles affect the model's responses
# 5. Exploring techniques for refining and improving role descriptions
#
# We'll use various examples to illustrate how role prompting can be applied in different scenarios, such as technical writing, creative storytelling, and professional advice-giving.
#
# ### Conclusion
# By the end of this tutorial, you will have a solid understanding of role prompting techniques and how to effectively implement them using Gemini and LangChain. You'll be equipped with the skills to craft compelling role descriptions and leverage them to enhance AI model performance in various applications.
#
# ### Setup
# First, let's import the necessary libraries and set up our environment.

# %%
import os
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# Load enviroment variables
from dotenv import load_dotenv
load_dotenv()

# Set up Google API key
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# Initialize the language model
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %% [markdown]
# ### Basic Role Assignment
# Let's start with a simple example of role assignment. We'll create a prompt that assigns the role of a technical writer to the AI model.

# %%
tech_writer_prompt = PromptTemplate(
    input_variables=["topic"],
    template="""You are a technical writer specializing in creating clear and concise documentation for software products.
    Your task is to write a brief explanation of {topic} for a user manual.
    Please provide a 2-3 sentence explanation that is easy for non-technical users to understand."""
)

chain = tech_writer_prompt | llm
response = chain.invoke({"topic": "cloud computing"})

# %% [markdown]
# ### Crafting Effective Role Descriptions
# Now, let's explore how to craft more detailed and effective role descriptions. We'll create a prompt for a financial advisor role with a more comprehensive description.

# %%
financial_advisor_prompt = PromptTemplate(
    input_variables=["client_situation"],
    template="""You are a seasoned financial advisor with over 20 years of experience in personal finance, investment strategies, and retirement planning.
    You have a track record of helping clients from diverse backgrounds achieve their financial goals.
    Your approach is characterized by:
    1. Thorough analysis of each client's unique financial situation
    2. Clear and jargon-free communication of complex financial concepts
    3. Ethical considerations in all recommendations
    4. A focus on long-term financial health and stability

    Given the following client situation, provide a brief (3-4 sentences) financial advice:
    {client_situation}

    Your response should reflect your expertise and adhere to your characteristic approach."""
)

chain = financial_advisor_prompt | llm
response = chain.invoke({"client_situation": "A 35-year-old professional earning $80,000 annually, with $30,000 in savings, no debt, and no retirement plan."})
print(response.content)
# Out:
# Given your solid financial foundation, let's prioritize establishing a retirement plan immediately. I recommend exploring tax-advantaged options like a 401(k) or Roth IRA, aiming to contribute at least enough to maximize any employer match if available. We can then diversify your savings into a balanced portfolio of stocks and bonds to capitalize on long-term growth potential, while maintaining a comfortable emergency fund. This proactive approach will set you on a strong path towards a secure financial future.

# %% [markdown]
# ### Comparing Responses with Different Roles
# To demonstrate how different roles can affect the AI's responses, let's create prompts for three different roles and compare their outputs on the same topic.

# %%
roles = [
    ("Scientist", "You are a research scientist specializing in climate change. Explain the following concept in scientific terms:"),
    ("Teacher", "You are a middle school science teacher. Explain the following concept in simple terms suitable for 12-year-old students:"),
    ("Journalist", "You are a journalist writing for a popular science magazine. Explain the following concept in an engaging and informative manner for a general adult audience:")
]

topic = "The greenhouse effect"

for role, description in roles:
    role_prompt = PromptTemplate(
        input_variables=["topic"],
        template=f"{description} {{topic}}"
    )
    chain = role_prompt | llm
    response = chain.invoke({"topic": topic})
    print(f"\n{role}'s explanation:\n")
    print(response.content)
    print("-" * 50)
# Out:
# Scientist's explanation:
#
# Okay, here's an explanation of the greenhouse effect, framed from the perspective of a research scientist specializing in climate change:
#
# **The Greenhouse Effect: A Radiative Energy Balance Perspective**
#
# The greenhouse effect is a naturally occurring process crucial for maintaining Earth's surface temperature within a range suitable for life. It's fundamentally a matter of radiative energy balance, specifically the interaction of solar radiation with the Earth's atmosphere and surface.
#
# **Here's a breakdown of the key components:**
#
# 1.  **Incoming Solar Radiation:** The Earth receives energy from the Sun primarily in the form of shortwave radiation, including visible light, ultraviolet (UV), and near-infrared radiation.  A portion of this incoming solar radiation (approximately 30%) is directly reflected back into space by clouds, aerosols, and reflective surfaces like ice and snow. This is characterized by the Earth's albedo.
#
# 2.  **Absorption and Surface Warming:** The remaining solar radiation is absorbed by the Earth's atmosphere and surface (land and oceans).  Absorption of this energy warms the planet's surface. The amount of warming depends on the surface albedo and the angle of incidence of the incoming radiation.
#
# 3.  **Infrared Emission:**  As the Earth's surface warms, it emits energy back into the atmosphere in the form of longwave radiation, specifically infrared (IR) radiation. The intensity and wavelength distribution of this emitted radiation are governed by the Stefan-Boltzmann law and Wien's displacement law, respectively, and are dependent on the surface temperature.
#
# 4.  **Greenhouse Gases and Atmospheric Absorption:** This is where the "greenhouse" effect comes into play. Certain gases in the atmosphere, known as greenhouse gases (GHGs), possess a molecular structure that allows them to efficiently absorb specific wavelengths of infrared radiation. Key GHGs include:
#
#     *   **Water Vapor (H₂O):** A dominant natural GHG, but its concentration is largely dependent on temperature and other climate variables, making it more of a feedback mechanism than a primary driver of long-term climate change.
#     *   **Carbon Dioxide (CO₂):** A significant GHG with a long atmospheric lifetime, primarily released through natural processes (respiration, volcanic eruptions) and human activities (fossil fuel combustion, deforestation).
#     *   **Methane (CH₄):** A potent GHG, though with a shorter atmospheric lifetime than CO₂, emitted from natural sources (wetlands, permafrost thaw) and anthropogenic sources (agriculture, natural gas leaks).
#     *   **Nitrous Oxide (N₂O):** A long-lived GHG emitted from agricultural practices, industrial processes, and combustion.
#     *   **Ozone (O₃):** While primarily known for its UV-absorbing role in the stratosphere, it also acts as a GHG in the troposphere.
#     *   **Halocarbons (e.g., CFCs, HFCs):** Synthetic gases, some of which are extremely potent GHGs with very long atmospheric lifetimes. Many are now regulated under international agreements due to their ozone-depleting potential.
#
#     When IR radiation emitted by the Earth's surface encounters these GHGs, the energy is absorbed, exciting the molecules to higher energy states.  These excited GHG molecules then re-emit the energy in all directions, both upwards into space and downwards back towards the Earth's surface.
#
# 5.  **Back Radiation and Surface Warming:** The downward-directed portion of the re-emitted IR radiation is known as "back radiation." This back radiation effectively traps heat within the lower atmosphere, further warming the Earth's surface and lower atmosphere beyond what would occur if there were no GHGs present.
#
# 6.  **The Equilibrium:** Eventually, the Earth reaches a radiative equilibrium where the amount of energy absorbed from the Sun is equal to the amount of energy radiated back into space.  The presence of GHGs shifts this equilibrium to a higher surface temperature than it would otherwise be.
#
# **In essence, the greenhouse effect acts like a blanket, trapping some of the Earth's outgoing heat and maintaining a habitable temperature.**
#
# **The Enhanced Greenhouse Effect and Climate Change:**
#
# The current concern regarding climate change stems from the *enhanced* greenhouse effect. Human activities, primarily the burning of fossil fuels, deforestation, and industrial processes, have significantly increased the concentrations of GHGs in the atmosphere, particularly CO₂. This increase in GHG concentrations leads to:
#
# *   **Increased Absorption:** A greater proportion of outgoing IR radiation is absorbed by the atmosphere.
# *   **Increased Back Radiation:** More energy is radiated back towards the Earth's surface.
# *   **Positive Radiative Forcing:** This imbalance between incoming solar radiation and outgoing infrared radiation creates a positive radiative forcing, meaning that more energy is being retained by the Earth system.
# *   **Global Warming:** The Earth's climate system responds to this radiative forcing by warming until a new equilibrium is established. This warming manifests as increases in global average surface temperature, changes in precipitation patterns, sea level rise, and other climate-related impacts.
#
# **Scientific Certainty and Ongoing Research:**
#
# The fundamental principles of the greenhouse effect are well-established and supported by a vast body of scientific evidence. Ongoing research focuses on:
#
# *   **Quantifying the climate sensitivity:** Determining the precise amount of warming expected for a given increase in GHG concentrations.
# *   **Understanding feedback mechanisms:** Investigating how changes in temperature, water vapor, ice cover, and other factors can amplify or dampen the initial warming effect.
# *   **Improving climate models:** Developing more sophisticated models to project future climate changes and assess the impacts of different emission scenarios.
# *   **Attributing climate change:** Determining the relative contributions of natural and human-caused factors to observed climate trends.
#
# In conclusion, the greenhouse effect is a natural and necessary process. However, human activities have enhanced this effect, leading to a significant increase in global temperatures and driving climate change. Understanding the underlying science is crucial for developing effective mitigation and adaptation strategies.
# --------------------------------------------------
#
# Teacher's explanation:
#
# Alright everyone, let's talk about the greenhouse effect!
#
# Imagine you're in a car on a sunny day, but the windows are all closed.  What happens inside the car?  It gets HOT, right?  That's kind of what's happening with the Earth and the greenhouse effect.
#
# Think of the Earth like that car, and the atmosphere (the air around us) like the car's windows. The sun's energy, mostly in the form of sunlight, shines down on Earth. Some of that sunlight is absorbed by the Earth's surface (land, oceans, plants), warming it up.
#
# Now, the Earth doesn't just keep getting hotter and hotter. It also releases energy back into space as heat.  Think of it like a hot stove cooling down.
#
# Here's where the "greenhouse" part comes in.  Certain gases in our atmosphere, called **greenhouse gases**, act like those car windows. They let the sunlight in, but they don't let all the heat escape back into space. They trap some of it, keeping the Earth warm enough for us to live comfortably.
#
# Think of these greenhouse gases like a cozy blanket around the Earth.  They're like:
#
# *   **Carbon Dioxide (CO2):** This comes from burning fossil fuels like coal, oil, and gas in cars, power plants, and factories.
# *   **Methane (CH4):** This comes from things like cows, rice paddies, and natural gas leaks.
# *   **Water Vapor (H2O):** This is the most abundant greenhouse gas, and it's created when water evaporates.
#
# **So, the greenhouse effect is basically this:**
#
# 1.  Sunlight shines on Earth.
# 2.  Earth absorbs some of the sunlight and warms up.
# 3.  Earth releases heat back into space.
# 4.  Greenhouse gases in the atmosphere trap some of that heat.
# 5.  This keeps the Earth warm enough for life.
#
# **Is the greenhouse effect a bad thing?**
#
# Not at all!  Without the greenhouse effect, Earth would be a frozen wasteland.  It's a natural and necessary process.
#
# **So what's the problem?**
#
# The problem is that we're putting *too many* greenhouse gases into the atmosphere by burning fossil fuels and doing other things. This is like putting too many blankets on your bed – you get too hot!  This is causing the Earth to warm up faster than it should, which can lead to problems like melting glaciers, rising sea levels, and more extreme weather.  This is what we call **global warming** or **climate change**.
#
# So, understanding the greenhouse effect is really important so we can understand how our actions are affecting the planet and think about ways to reduce our impact! Any questions?
# --------------------------------------------------
#
# Journalist's explanation:
#
# ## The Earth's Cozy Blanket: Understanding the Greenhouse Effect
#
# Imagine stepping into a greenhouse on a chilly day. Suddenly, you're bathed in warmth, even though the outside temperature is still nippy. That feeling, in a nutshell, is the greenhouse effect at work. And lucky for us, a similar, albeit more subtle, process keeps our entire planet habitable.
#
# The greenhouse effect is a natural phenomenon that traps some of the Sun's energy in the Earth's atmosphere, warming our planet. Think of it as the Earth wearing a cozy blanket of gases that prevents too much heat from escaping into space. Without it, our planet would be a frozen wasteland, averaging around a bone-chilling -18°C (0°F)!
#
# **So, how does this "blanket" work?**
#
# It all starts with the Sun's energy. This energy, in the form of sunlight, travels millions of miles to reach Earth. About 30% of that sunlight is immediately reflected back into space by clouds, ice, and other reflective surfaces. The remaining 70% is absorbed by the Earth's surface – land, oceans, and the atmosphere itself.
#
# This absorbed energy warms the Earth, causing it to emit infrared radiation, which is essentially heat. Now, here's where the "greenhouse" part comes in.
#
# Certain gases in our atmosphere, known as **greenhouse gases**, are particularly good at absorbing this infrared radiation. These gases act like the glass roof of a greenhouse, allowing sunlight to pass through but trapping some of the heat inside. The most important greenhouse gases include:
#
# *   **Water vapor (H₂O):** The most abundant greenhouse gas, playing a crucial role in regulating temperature.
# *   **Carbon dioxide (CO₂):** Released through natural processes like respiration and volcanic eruptions, but also significantly increased by human activities like burning fossil fuels.
# *   **Methane (CH₄):** A potent greenhouse gas emitted from livestock, natural gas leaks, and decaying organic matter.
# *   **Nitrous oxide (N₂O):** Released from agricultural and industrial activities, as well as the burning of fossil fuels.
#
# When these greenhouse gases absorb infrared radiation, they re-emit it in all directions. Some of this re-emitted heat goes back towards the Earth's surface, further warming the planet. This continuous cycle of absorption and re-emission is what maintains a comfortable temperature on Earth.
#
# **The Problem: Too Much of a Good Thing?**
#
# The greenhouse effect is essential for life as we know it. However, human activities, particularly the burning of fossil fuels, deforestation, and industrial processes, have significantly increased the concentration of greenhouse gases in the atmosphere.
#
# This increase is like adding extra layers to our Earth's blanket. More heat gets trapped, leading to a phenomenon known as **global warming** or **climate change**. This excess warming is causing a range of problems, including rising sea levels, more frequent and intense heatwaves, disruptions to weather patterns, and threats to ecosystems.
#
# **What can we do?**
#
# Understanding the greenhouse effect is the first step towards tackling climate change. By reducing our emissions of greenhouse gases through things like transitioning to renewable energy sources, improving energy efficiency, and adopting sustainable agricultural practices, we can help stabilize the Earth's climate and ensure a healthy planet for future generations.
#
# So, the next time you step into a greenhouse, remember the vital role this natural process plays in keeping our planet warm and habitable. But also remember the responsibility we have to manage our greenhouse gas emissions and protect our Earth's cozy blanket from becoming too thick.
# --------------------------------------------------

# %% [markdown]
# ### Refining Role Descriptions
# Let's explore how to refine role descriptions for more specific outcomes. We'll use a creative writing example, focusing on different storytelling styles.

# %%
storyteller_prompt = PromptTemplate(
    input_variables=["style", "scenario"],
    template="""You are a master storyteller known for your ability to adapt to various narrative styles.
    Your current task is to write in the style of {style}.
    Key characteristics of this style include:
    1. {style_char1}
    2. {style_char2}
    3. {style_char3}

    Write a short paragraph (3-4 sentences) in this style about the following scenario:
    {scenario}

    Ensure your writing clearly reflects the specified style."""
)

styles = [
    {
        "name": "Gothic horror",
        "char1": "Atmospheric and ominous descriptions",
        "char2": "Themes of decay, death, and the supernatural",
        "char3": "Heightened emotions and sense of dread"
    },
    {
        "name": "Minimalist realism",
        "char1": "Sparse, concise language",
        "char2": "Focus on everyday, ordinary events",
        "char3": "Subtle implications rather than explicit statements"
    }
]

scenario = "A person enters an empty house at twilight"

for style in styles:
    chain = storyteller_prompt | llm
    response = chain.invoke({
        "style": style["name"],
        "style_char1": style["char1"],
        "style_char2": style["char2"],
        "style_char3": style["char3"],
        "scenario": scenario
    })
    print(f"\n{style['name']} version:\n")
    print(response.content)
    print("-" * 50)
# Out:
# Gothic horror version:
#
# The last sliver of sun bled across the horizon as I pushed the warped oak door inward, the hinges groaning like a tormented soul. Dust motes danced in the fading light, illuminating cobwebs thick as shrouds draped across the furniture. A chilling stillness permeated the air, heavy with the scent of mildew and forgotten things, promising secrets best left undisturbed within the decaying heart of the house.
# --------------------------------------------------
#
# Minimalist realism version:
#
# The door clicked shut. Dust motes danced in the fading light. She set her bag down, the sound loud in the quiet house. Upstairs, a floorboard creaked.
# --------------------------------------------------
