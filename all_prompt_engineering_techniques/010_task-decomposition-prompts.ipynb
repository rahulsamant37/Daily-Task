# %% [markdown]
# # Task Decomposition in Prompts Tutorial
# ### Overview
# This tutorial explores the concept of task decomposition in prompt engineering, focusing on techniques for breaking down complex tasks and chaining subtasks in prompts. These techniques are essential for effectively leveraging large language models to solve multi-step problems and perform complex reasoning tasks.
#
# ### Motivation
# As AI language models become more advanced, they are increasingly capable of handling complex tasks. However, these models often perform better when given clear, step-by-step instructions. Task decomposition is a powerful technique that allows us to break down complex problems into smaller, more manageable subtasks. This approach not only improves the model's performance but also enhances the interpretability and reliability of the results.
#
# ### Key Components
# 1. Breaking Down Complex Tasks: Techniques for analyzing and dividing complex problems into simpler subtasks.
# 2. Chaining Subtasks: Methods for sequentially connecting multiple subtasks to solve a larger problem.
# 3. Prompt Design for Subtasks: Crafting effective prompts for each decomposed subtask.
# 4. Result Integration: Combining the outputs from individual subtasks to form a comprehensive solution.
# ### Method Details
# The tutorial employs a step-by-step approach to demonstrate task decomposition:
#
# 1. Problem Analysis: We start by examining a complex task and identifying its component parts.
# 2. Subtask Definition: We define clear, manageable subtasks that collectively address the main problem.
# 3. Prompt Engineering: For each subtask, we create targeted prompts that guide the AI model.
# 4. Sequential Execution: We implement a chain of prompts, where the output of one subtask feeds into the next.
# 5. Result Synthesis: Finally, we combine the outputs from all subtasks to form a comprehensive solution.
#
# Throughout the tutorial, we use practical examples to illustrate these concepts, demonstrating how task decomposition can be applied to various domains such as analysis, problem-solving, and creative tasks.
#
# ### Conclusion
# By the end of this tutorial, learners will have gained practical skills in:
#
# - Analyzing complex tasks and breaking them down into manageable subtasks
# - Designing effective prompts for each subtask
# - Chaining prompts to guide an AI model through a multi-step reasoning process
# - Integrating results from multiple subtasks to solve complex problems
#
# These skills will enable more effective use of AI language models for complex problem-solving and enhance the overall quality and reliability of AI-assisted tasks.
#
# ### Setup
# First, let's import the necessary libraries and set up our environment.

# %%
import os
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# Load enviroment variables
from dotenv import load_dotenv
load_dotenv()

# Set up Google API key
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# Initialize the language model
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

def run_prompt(prompt, **kwargs):
    """Helper function to run a prompt through the language model.

    Args:
        prompt (str): The prompt template string.
        **kwargs: Keyword arguments to fill the prompt template.

    Returns:
        str: The model's response.
    """
    prompt_template = PromptTemplate(template=prompt, input_variables=list(kwargs.keys()))
    chain = prompt_template | llm
    return chain.invoke(kwargs).content

# %% [markdown]
# ### Breaking Down Complex Tasks
# Let's start with a complex task and break it down into subtasks. We'll use the example of analyzing a company's financial health.

# %%
complex_task = """
Analyze the financial health of a company based on the following data:
- Revenue: $10 million
- Net Income: $2 million
- Total Assets: $15 million
- Total Liabilities: $7 million
- Cash Flow from Operations: $3 million
"""

decomposition_prompt = """
Break down the task of analyzing a company's financial health into 3 subtasks. For each subtask, provide a brief description of what it should accomplish.

Task: {task}

Subtasks:
1.
"""

subtasks = run_prompt(decomposition_prompt, task=complex_task)
print(subtasks)
# Out:
# Here's a breakdown of the task into three subtasks, along with descriptions of what each should accomplish:
#
# **Subtask 1: Profitability Analysis**
#
# *   **Description:** This subtask focuses on evaluating the company's ability to generate profits from its revenue. It will calculate and interpret key profitability ratios using the provided revenue and net income data. The goal is to understand how efficiently the company is converting revenue into profit.
#
# **Subtask 2: Liquidity and Solvency Analysis**
#
# *   **Description:** This subtask assesses the company's ability to meet its short-term and long-term financial obligations. It will utilize the total assets and total liabilities data to calculate and analyze liquidity ratios (like current ratio) and solvency ratios (like debt-to-equity ratio). The goal is to determine if the company has enough assets to cover its liabilities and is not overly reliant on debt.
#
# **Subtask 3: Cash Flow Adequacy Analysis**
#
# *   **Description:** This subtask examines the company's ability to generate cash from its core business operations. It will analyze the provided Cash Flow from Operations figure in relation to other data points, such as net income and total liabilities. The goal is to determine if the company is generating sufficient cash flow to support its operations, invest in growth, and meet its debt obligations.

# %% [markdown]
# ### Chaining Subtasks in Prompts
# Now that we have our subtasks, let's create individual prompts for each and chain them together.

# %%
def analyze_profitability(revenue, net_income):
    """Analyze the company's profitability.

    Args:
        revenue (float): Company's revenue.
        net_income (float): Company's net income.

    Returns:
        str: Analysis of the company's profitability.
    """
    prompt = """
    Analyze the company's profitability based on the following data:
    - Revenue: ${revenue} million
    - Net Income: ${net_income} million

    Calculate the profit margin and provide a brief analysis of the company's profitability.
    """
    return run_prompt(prompt, revenue=revenue, net_income=net_income)

def analyze_liquidity(total_assets, total_liabilities):
    """Analyze the company's liquidity.

    Args:
        total_assets (float): Company's total assets.
        total_liabilities (float): Company's total liabilities.

    Returns:
        str: Analysis of the company's liquidity.
    """
    prompt = """
    Analyze the company's liquidity based on the following data:
    - Total Assets: ${total_assets} million
    - Total Liabilities: ${total_liabilities} million

    Calculate the current ratio and provide a brief analysis of the company's liquidity.
    """
    return run_prompt(prompt, total_assets=total_assets, total_liabilities=total_liabilities)

def analyze_cash_flow(cash_flow):
    """Analyze the company's cash flow.

    Args:
        cash_flow (float): Company's cash flow from operations.

    Returns:
        str: Analysis of the company's cash flow.
    """
    prompt = """
    Analyze the company's cash flow based on the following data:
    - Cash Flow from Operations: ${cash_flow} million

    Provide a brief analysis of the company's cash flow health.
    """
    return run_prompt(prompt, cash_flow=cash_flow)

# Run the chained subtasks
profitability_analysis = analyze_profitability(10, 2)
liquidity_analysis = analyze_liquidity(15, 7)
cash_flow_analysis = analyze_cash_flow(3)

print("Profitability Analysis:\n", profitability_analysis)
print("\nLiquidity Analysis:\n", liquidity_analysis)
print("\nCash Flow Analysis:\n", cash_flow_analysis)
# Out:
# Profitability Analysis:
#  Okay, let's analyze the company's profitability.
#
# **1. Calculate the Profit Margin:**
#
# Profit Margin (Net Profit Margin) = (Net Income / Revenue) * 100
#
# Profit Margin = ($2,000,000 / $10,000,000) * 100
#
# Profit Margin = 0.20 * 100
#
# Profit Margin = 20%
#
# **2. Analysis of Profitability:**
#
# A profit margin of 20% indicates that the company is retaining 20 cents of every dollar of revenue as profit after all expenses have been paid.
#
# **Here's a brief analysis:**
#
# *   **Generally Good:** A 20% profit margin is generally considered a good and healthy profit margin. It suggests the company is efficient in managing its costs and converting revenue into profit.
#
# *   **Industry Context is Crucial:**  The real interpretation of this profit margin depends heavily on the industry the company operates in.
#     *   Some industries (e.g., software, pharmaceuticals) often have higher profit margins due to lower cost of goods sold and high value-added products/services.
#     *   Other industries (e.g., retail, manufacturing) tend to have lower profit margins due to higher operating costs and competitive pricing.
#
# *   **Comparison to Competitors:** To get a better understanding, it's important to compare this 20% profit margin to the average profit margins of its direct competitors and the industry as a whole. If the company's profit margin is higher than its competitors, it suggests a competitive advantage (e.g., better cost control, stronger brand, more efficient operations). If it's lower, it may indicate areas for improvement.
#
# *   **Trend Analysis:** It's also important to analyze the trend of the profit margin over time. Is it increasing, decreasing, or staying consistent? A declining profit margin could be a warning sign of rising costs, increased competition, or pricing pressures.
#
# **In summary:**
#
# The company has a respectable 20% profit margin. However, to fully assess its profitability, you need to compare it to industry benchmarks, competitors' performance, and the company's own historical performance. Without this context, it's difficult to definitively say whether the company's profitability is excellent, average, or needs improvement.
#
# Liquidity Analysis:
#  Okay, let's analyze the company's liquidity using the provided data.  While the data is limited, we can still calculate a key liquidity ratio and draw some basic conclusions.
#
# **1. Limitations of the Data:**
#
# It's important to acknowledge that **Total Assets and Total Liabilities are not sufficient to perform a thorough liquidity analysis.**  Liquidity focuses on a company's *short-term* ability to meet its obligations.  We need data specifically about:
#
# *   **Current Assets:**  Assets that can be converted into cash within one year (e.g., cash, accounts receivable, inventory).
# *   **Current Liabilities:**  Obligations due within one year (e.g., accounts payable, short-term debt).
#
# Without these, we can only make a very general assessment.  We'll have to *assume* some relationship between total assets/liabilities and their current components.
#
# **2. Assumptions:**
#
# Since we only have Total Assets and Total Liabilities, we'll have to make a simplifying assumption.  Let's assume that a reasonable portion of Total Assets is Current Assets and a reasonable portion of Total Liabilities is Current Liabilities. This is a HUGE assumption.
#
# *   **Assumption 1:** 40% of Total Assets are Current Assets.  This implies Current Assets = 0.40 * $15 million = $6 million
# *   **Assumption 2:** 60% of Total Liabilities are Current Liabilities. This implies Current Liabilities = 0.60 * $7 million = $4.2 million
#
# **3. Calculation of Current Ratio (with Assumptions):**
#
# The current ratio is calculated as:
#
# *   **Current Ratio = Current Assets / Current Liabilities**
#
# Using our assumed values:
#
# *   Current Ratio = $6 million / $4.2 million = 1.43
#
# **4. Analysis of Liquidity (Based on Assumptions):**
#
# Based on the calculated current ratio of 1.43 (and remember, this is *highly dependent* on our assumptions):
#
# *   **Interpretation:** A current ratio of 1.43 suggests that the company has $1.43 of current assets for every $1 of current liabilities.
#
# *   **General Assessment:** Generally, a current ratio between 1.5 and 2.0 is considered healthy.  A ratio below 1.0 might indicate potential liquidity problems, while a ratio significantly above 2.0 *could* suggest that the company isn't efficiently using its current assets (although this is not necessarily a bad thing).
#
# *   **Caveats:**
#
#     *   **Industry Specificity:** The ideal current ratio varies significantly by industry.  Industries with fast inventory turnover (e.g., grocery stores) can often operate with lower current ratios.  Industries with longer production cycles (e.g., construction) typically need higher ratios.
#     *   **Quality of Current Assets:** The *quality* of current assets is crucial.  For example, accounts receivable that are unlikely to be collected or obsolete inventory are not truly liquid.
#     *   **Timing:** Liquidity is a snapshot in time.  It can change rapidly.
#
# **5. Conclusion:**
#
# Based on the extremely limited data and our assumptions, the company *appears* to have adequate liquidity, but further analysis is needed. **It is impossible to make a definitive statement about the company's liquidity without knowing the actual values of Current Assets and Current Liabilities.** A proper assessment requires access to the company's balance sheet and ideally other financial statements.
#
# **Recommendation:**
#
# To provide a meaningful analysis, you absolutely need the following:
#
# *   **Balance Sheet:**  The actual balance sheet is essential to obtain the real values of Current Assets and Current Liabilities.
# *   **Industry Benchmarks:**  Compare the company's current ratio to the average for its industry.
# *   **Trend Analysis:**  Look at the company's current ratio over time to identify any trends.
# *   **Cash Flow Statement:**  Review the cash flow statement to understand how the company generates and uses cash.
# *   **Notes to Financial Statements:**  Read the notes to the financial statements for important details about the company's accounting policies and potential risks.
#
# Cash Flow Analysis:
#  A Cash Flow from Operations (CFO) of $3 million indicates that the company is generating cash from its core business activities.  This is generally a **positive sign** and suggests the business is profitable and efficient at converting sales into cash.
#
# **Here's a brief analysis of the company's cash flow health based solely on this information:**
#
# *   **Positive Indicator:** The company is generating cash from its operations, which is crucial for funding investments, paying down debt, and returning value to shareholders.
#
# *   **Self-Sufficiency:**  Positive CFO suggests the company is not reliant on external financing (like borrowing) to cover its day-to-day expenses.
#
# *   **Limited Information:** Without additional context, such as the company's size, industry, and historical performance, it's difficult to assess the significance of this $3 million. For example, $3 million might be excellent for a small startup but insufficient for a large corporation.
#
# **To get a more complete picture of the company's cash flow health, you'd need to consider:**
#
# *   **Cash Flow from Investing (CFI):**  Is the company investing in growth opportunities or selling off assets?
# *   **Cash Flow from Financing (CFF):** Is the company borrowing money or paying down debt?  Is it issuing stock or buying back shares?
# *   **Trend Analysis:**  How does the current CFO compare to previous periods?  Is it increasing or decreasing?
# *   **Industry Benchmarks:** How does the company's CFO compare to its competitors?
# *   **Net Income:** How does the CFO compare to the company's net income?  A significant difference might indicate issues with accrual accounting.
#
# **In conclusion, a CFO of $3 million is a good starting point, but further analysis is necessary to determine the overall health and sustainability of the company's cash flow.**

# %% [markdown]
# ### Integrating Results
# Finally, let's integrate the results from our subtasks to provide an overall analysis of the company's financial health.

# %%
def integrate_results(profitability, liquidity, cash_flow):
    """Integrate the results from subtasks to provide an overall analysis.

    Args:
        profitability (str): Profitability analysis.
        liquidity (str): Liquidity analysis.
        cash_flow (str): Cash flow analysis.

    Returns:
        str: Overall analysis of the company's financial health.
    """
    prompt = """
    Based on the following analyses, provide an overall assessment of the company's financial health:

    Profitability Analysis:
    {profitability}

    Liquidity Analysis:
    {liquidity}

    Cash Flow Analysis:
    {cash_flow}

    Summarize the key points and give an overall evaluation of the company's financial position.
    """
    return run_prompt(prompt, profitability=profitability, liquidity=liquidity, cash_flow=cash_flow)

overall_analysis = integrate_results(profitability_analysis, liquidity_analysis, cash_flow_analysis)
print("Overall Financial Health Analysis:\n", overall_analysis)
# Out:
# Overall Financial Health Analysis:
#  Okay, here's an overall assessment of the company's financial position, based on the provided analyses. Keep in mind that this is a preliminary evaluation due to the limited data available.
#
# **Key Points Summary:**
#
# *   **Profitability:** The company has a 20% profit margin, which is generally good. However, its true significance depends on industry benchmarks, competitor performance, and historical trends. More context is needed to determine if this is excellent, average, or needs improvement.
#
# *   **Liquidity:**  Based on *significant* assumptions due to limited data (only Total Assets and Total Liabilities were available), the company *appears* to have a current ratio of 1.43.  This *suggests* adequate liquidity, but this conclusion is highly tentative.  A proper liquidity assessment requires actual Current Assets and Current Liabilities figures, along with industry comparisons and trend analysis.
#
# *   **Cash Flow:** The company has a Cash Flow from Operations (CFO) of $3 million, which indicates the company is generating cash from its core business activities. This is a positive sign. However, without knowing the company's size, industry, or historical performance, it's difficult to assess the significance of this amount. The analysis also needs to consider Cash Flow from Investing and Cash Flow from Financing.
#
# **Overall Evaluation (Preliminary and Cautious):**
#
# Based on the available information, the company appears to be in a reasonably healthy financial position.  It's profitable and generating cash from its operations.  Liquidity *may* be adequate, but this is the weakest conclusion due to the data limitations.
#
# **Areas of Concern and Recommendations:**
#
# *   **Data Scarcity:** The biggest limitation is the lack of detailed financial data. The analysis relies heavily on assumptions, particularly for liquidity.
#
# *   **Need for Context:** All the key metrics (profit margin, current ratio, CFO) require context for proper interpretation. This includes:
#     *   **Industry Benchmarks:** Comparing the company's performance to industry averages.
#     *   **Competitor Analysis:** Comparing the company's performance to its direct competitors.
#     *   **Trend Analysis:** Analyzing the company's performance over time.
#
# *   **Specific Data Requirements:** To provide a more accurate assessment, the following information is crucial:
#     *   **Complete Balance Sheet:**  Especially Current Assets and Current Liabilities.
#     *   **Complete Cash Flow Statement:** Including Cash Flow from Investing and Cash Flow from Financing.
#     *   **Income Statement:**  For at least the past few years to track trends in profitability.
#     *   **Industry Information:**  Industry-specific benchmarks for profitability and liquidity.
#
# **In conclusion, while the initial signs are positive, a definitive assessment of the company's financial health cannot be made without access to more comprehensive financial data and a thorough analysis of the industry and competitive landscape.**  The current analysis is more of a starting point than a final judgment.
