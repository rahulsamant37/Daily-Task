# %% [markdown]
# # Prompt Optimization Techniques
# ### Overview
# This tutorial explores advanced techniques for optimizing prompts when working with large language models. We focus on two key strategies: A/B testing prompts and iterative refinement. These methods are crucial for improving the effectiveness and efficiency of AI-driven applications.
#
# ### Motivation
# As AI language models become more sophisticated, the quality of prompts used to interact with them becomes increasingly important. Optimized prompts can lead to more accurate, relevant, and useful responses, enhancing the overall performance of AI applications. This tutorial aims to equip learners with practical techniques to systematically improve their prompts.
#
# ### Key Components
# 1. A/B Testing Prompts: A method to compare the effectiveness of different prompt variations.
# 2. Iterative Refinement: A strategy for gradually improving prompts based on feedback and results.
# 3. Performance Metrics: Ways to measure and compare the quality of responses from different prompts.
# 4. Practical Implementation: Hands-on examples using Gemini model and LangChain.
# ### Method Details
# 1. Setup: We'll start by setting up our environment with the necessary libraries and API keys.
#
# 2. A/B Testing:
#
# - Define multiple versions of a prompt
# - Generate responses for each version
# - Compare results using predefined metrics
# 3. Iterative Refinement:
#
# - Start with an initial prompt
# - Generate responses and evaluate
# - Identify areas for improvement
# - Refine the prompt based on insights
# - Repeat the process to continuously enhance the prompt
# 4. Performance Evaluation:
#
# - Define relevant metrics (e.g., relevance, specificity, coherence)
# - Implement scoring functions
# - Compare scores across different prompt versions
#
# Throughout the tutorial, we'll use practical examples to demonstrate these techniques, providing learners with hands-on experience in prompt optimization.
#
# ### Conclusion
# By the end of this tutorial, learners will have gained:
#
# 1. Practical skills in conducting A/B tests for prompt optimization
# 2. Understanding of iterative refinement processes for prompts
# 3. Ability to define and use metrics for evaluating prompt effectiveness
# 4. Hands-on experience with Gemini and LangChain libraries for prompt optimization
#
# These skills will enable learners to create more effective AI applications by systematically improving their interaction with language models.
#
# ### Setup
# First, let's import the necessary libraries and set up our environment.

# %%
import os
import re
import numpy as np

from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# Load enviroment variables
from dotenv import load_dotenv
load_dotenv()

# Set up Google API key
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# Initialize the language model
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# Define a helper function to generate responses
def generate_response(prompt):
    """Generate a response using the language model.

    Args:
        prompt (str): The input prompt.

    Returns:
        str: The generated response.
    """
    return llm.invoke(prompt).content

# %% [markdown]
# ### A/B Testing Prompts
# Let's start with A/B testing by comparing different prompt variations for a specific task.

# %%
prompt_a = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms."
)

prompt_b = PromptTemplate(
    input_variables=["topic"],
    template="Provide a begginer-friendly explanation of {topic}, inculding key concepts and an example."
)

# Updated function to evaluate reponse quality
def evaluate_response(response, criteria):
    """Evaluate the quality of a response based on given criteria.

    Args:
        response (str): The generated response.
        criteria (list): List of criteria to evaluate.

    Returns:
        float: The average score across all criteria.
    """
    scores = []
    for criterion in criteria:
        print(f"Evaluating response based on {criterion}...")
        prompt = f"On a scale of 1-10, rate the following response on {criterion}. Start your response with the numeric score:\n\n{response}"
        response = generate_response(prompt)
        # show 50 characters of the response
        # Use regex to find the first number in the response
        score_match = re.search(r"\d+", response)
        if score_match:
            score = int(score_match.group())
            scores.append(min(score, 10)) # Ensure score is not greater than 10
        else:
            print(f"Warning: Could not extract numeric score for {criterion}. Using default score of 5.")
            scores.append(5)  # Default score if no number is found
    return np.mean(scores)

# Perform A/B test
topic = "machine learning"
response_a = generate_response(prompt_a.format(topic=topic))
response_b = generate_response(prompt_b.format(topic=topic))

criteria = ["clarity", "informativeness", "engagement"]
score_a = evaluate_response(response_a, criteria)
score_b = evaluate_response(response_b, criteria)

print(f"Prompt A score: {score_a:.2f}")
print(f"Prompt B score: {score_b:.2f}")
print(f"Winning prompt: {'A' if score_a > score_b else 'B'}")
# Out:
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Warning: Could not extract numeric score for engagement. Using default score of 5.
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Prompt A score: 7.67
# Prompt B score: 9.00
# Winning prompt: B

# %% [markdown]
# ### Iterative Refinement
# Now, let's demonstrate the iterative refinement process for improving a prompt.

# %%
def refine_prompt(initial_prompt, topic, iterations=3):
    """Refine a prompt through multiple iterations.

    Args:
        initial_prompt (PromptTemplate): The starting prompt template.
        topic (str): The topic to explain.
        iterations (int): Number of refinement iterations.

    Returns:
        PromptTemplate: The final refined prompt template.
    """
    current_prompt = initial_prompt
    for i in range(iterations):
        try:
            response = generate_response(current_prompt.format(topic=topic))
        except KeyError as e:
            print(f"Error in iteration {i+1}: Missing key {e}. Adjusting prompt...")
            # Remove the problematic placeholder
            current_prompt.template = current_prompt.template.replace(f"{{{e.args[0]}}}", "relevant example")
            response = generate_response(current_prompt.format(topic=topic))
        
        # Generate feedback and suggestions for improvement
        feedback_prompt = f"Analyze the following explanation of {topic} and suggest improvements to the prompt that generated it:\n\n{response}"
        feedback = generate_response(feedback_prompt)
        
        # Use the feedback to refine the prompt
        refine_prompt = f"Based on this feedback: '{feedback}', improve the following prompt template. Ensure to only use the variable {{topic}} in your template:\n\n{current_prompt.template}"
        refined_template = generate_response(refine_prompt)
        
        current_prompt = PromptTemplate(
            input_variables=["topic"],
            template=refined_template
        )
        
        print(f"Iteration {i+1} prompt: {current_prompt.template}")
    
    return current_prompt

# Perform A/B test
topic = "machine learning"
response_a = generate_response(prompt_a.format(topic=topic))
response_b = generate_response(prompt_b.format(topic=topic))

criteria = ["clarity", "informativeness", "engagement"]
score_a = evaluate_response(response_a, criteria)
score_b = evaluate_response(response_b, criteria)

print(f"Prompt A score: {score_a:.2f}")
print(f"Prompt B score: {score_b:.2f}")
print(f"Winning prompt: {'A' if score_a > score_b else 'B'}")

# Start with the winning prompt from A/B testing
initial_prompt = prompt_b if score_b > score_a else prompt_a
refined_prompt = refine_prompt(initial_prompt, "machine learning")

print("\nFinal refined prompt:")
print(refined_prompt.template)
# Out:
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Prompt A score: 7.33
# Prompt B score: 8.67
# Winning prompt: B
# Iteration 1 prompt: Okay, based on the feedback, here are several improved prompt templates, each focusing on a different approach as suggested in the analysis:
#
# **Option 1: Focus on a Specific Learning Type**
#
# "Explain {topic} (specifically, focus on supervised learning aspects if applicable) to someone with no prior knowledge. Use a clear analogy. Provide a detailed example, including how a model is trained (if relevant to {topic}), and explain the importance of feature selection. Discuss potential issues like overfitting and underfitting (if applicable to {topic}). Do not exceed 1000 words."
#
# **Option 2: Target a Specific Audience (adapt the audience description to the context of {topic})**
#
# "Explain the business applications of {topic} to a non-technical audience of business professionals. Focus on how {topic} can be used to improve decision-making, automate processes, and personalize customer experiences. Provide real-world examples of companies using {topic} successfully. Avoid technical jargon and focus on the business benefits. Do not exceed 750 words."
#
# **Option 3: Request a Comparison (if {topic} lends itself to comparison with other concepts)**
#
# "Compare and contrast {topic} with two other related concepts (specify the related concepts in the actual prompt, e.g., "Linear Regression" and "Decision Trees" if {topic} is "Neural Networks"). For each, explain its strengths, weaknesses, and appropriate use cases. Provide a simple example of a problem that each could be used to solve. Explain the trade-offs between complexity and interpretability. Do not exceed 1200 words."
#
# **Option 4: Include a Visual Component (description of visuals)**
#
# "Explain {topic} to someone with no prior knowledge. Provide an analogy to help understanding. Describe the core components and how they interact. Include detailed *descriptions* of diagrams that would help illustrate these concepts (e.g., a diagram showing the structure, a diagram showing the flow of information). Do not exceed 1000 words."
#
# **Option 5: A more generally improved template**
#
# "Explain {topic} in a beginner-friendly way. Use an analogy to make it easier to understand. Provide a concrete example to illustrate the concept. Explain the key concepts, and why they are important. Include a section on potential challenges or limitations of {topic}. Explain this in a friendly and engaging tone. Do not exceed 800 words. Summarize the main points at the end."
#
# **Key Improvements Incorporated:**
#
# *   **Specificity:**  The templates are designed to encourage a more focused response by prompting for analogies, examples, and discussion of limitations.
# *   **Control:** Word limits are included to manage the depth of the response.
# *   **Audience Awareness:** One template explicitly targets a business audience.
# *   **Visual Thinking:** One template prompts for descriptions of visuals.
# *   **Proactive Problem Solving:** The inclusion of "potential challenges or limitations" encourages a more balanced and realistic explanation.
# *   **Tone Control:** Suggestion to use a friendly tone
# *   **Reinforcement:** Suggestion to summarize the main points.
#
# **How to Choose the Best Template:**
#
# The best template will depend on what you want to learn about {topic}.
#
# *   If you want a comprehensive overview, use **Option 5**.
# *   If you want to understand the business value, use **Option 2**.
# *   If you want to compare it to other concepts, use **Option 3**.
# *   If you want to understand the underlying mechanics better, use **Option 1** or **Option 4**.
#
# Remember to replace `{topic}` with the actual topic you want to explore.  And feel free to further customize these templates to fit your specific needs!
# Iteration 2 prompt: Okay, here are five improved prompt templates, focusing on different approaches, incorporating the previous feedback and maintaining only the `{topic}` variable:
#
# **Option 1: Structured Explanation with Analogy and Example**
#
# "Explain {topic} to someone with no prior knowledge.  Use the analogy of [Suggest a specific analogy, e.g., a baker making bread] to illustrate the core concepts. Provide a concrete example related to [Suggest a specific example, e.g., predicting customer churn].  Explain the key steps involved, including [Suggest a specific step, e.g., data preprocessing]. Discuss potential challenges or limitations, such as [Suggest a specific limitation, e.g., biased data].  Structure your response in a clear, step-by-step manner.  Maximum 800 words."
#
# **Option 2: Business-Focused Explanation with Real-World Examples**
#
# "Explain the business applications of {topic} in the [Suggest a specific industry, e.g., retail] industry to a non-technical audience.  Focus on how {topic} can improve [Suggest a specific business outcome, e.g., inventory management] and [Suggest another specific business outcome, e.g., customer acquisition]. Provide 2-3 real-world examples of companies successfully using {topic} in this industry.  Avoid technical jargon and emphasize the return on investment (ROI). Maximum 750 words."
#
# **Option 3: Comparative Analysis with Strengths, Weaknesses, and Use Cases**
#
# "Compare and contrast {topic} with [Suggest a specific related concept, e.g., regression analysis] and [Suggest another specific related concept, e.g., clustering].  Present your comparison in a tabular format, highlighting the strengths, weaknesses, and appropriate use cases of each.  For each concept, provide a simple example of a problem it could be used to solve, focusing on [Suggest a specific type of problem, e.g., classification].  Explain the trade-offs between complexity, interpretability, and accuracy. Maximum 1000 words."
#
# **Option 4: Deep Dive with Visual Component Description**
#
# "Explain {topic} to someone with no prior knowledge, assuming they understand basic [Suggest a prerequisite concept, e.g., programming concepts].  Use the analogy of [Suggest a specific analogy, e.g., a plumbing system] to explain the flow of information or processes.  Describe in detail a diagram that would illustrate [Suggest a specific element to illustrate, e.g., the architecture of a neural network] or [Suggest another element to illustrate, e.g., the decision-making process of an algorithm]. Explain how the different components interact. Maximum 900 words."
#
# **Option 5: Seeded, Beginner-Friendly Explanation with Summary**
#
# "Explain {topic} in a beginner-friendly and engaging way to a [Suggest a target audience, e.g., high school student].  Seed the response with the following sentence: '[Suggest a starting sentence to guide the response, e.g., {topic} is like teaching a computer to learn from examples.]' Use a concrete example related to [Suggest a specific example domain, e.g., image recognition] to illustrate the concept. Explain the key concepts and their importance in simple terms.  Include a section on potential challenges or limitations.  Summarize the main points in a concise conclusion. Maximum 700 words."
#
# **Key Improvements:**
#
# *   **Specificity in Suggestions:** The templates now include bracketed suggestions for specific analogies, examples, industries, concepts, and business outcomes. This guides the user to provide more targeted input.
# *   **Tabular Format:** Option 3 explicitly requests a tabular format for clarity.
# *   **Seeding:** Option 5 incorporates the "seed" concept to guide the initial direction.
# *   **Prerequisite Knowledge:** Option 4 acknowledges potential prerequisite knowledge.
# *   **ROI Focus:** Option 2 emphasizes return on investment.
# *   **Controlled Length:** Word limits are maintained.
# *   **Audience Targeting:** Option 5 includes specifying a target audience.
#
# These templates should provide a solid foundation for generating high-quality explanations of {topic} based on the user's specific needs. Remember to replace the bracketed suggestions with concrete values when using the templates.
# Iteration 3 prompt: This is a significant improvement! The prompt templates are now much more structured and provide helpful guidance for the user. The bracketed suggestions are excellent, as they offer concrete ideas and reduce ambiguity.  The inclusion of word limits is also a good practice.
#
# Here are a few minor suggestions for even further refinement, focusing on clarity and consistency:
#
# **Option 1: Structured Explanation with Analogy and Example**
#
# "Explain {topic} to someone with no prior knowledge. Use the analogy of [Suggest a specific analogy, e.g., a baker making bread] to illustrate the core concepts. Provide a concrete example related to [Suggest a specific application area, e.g., predicting customer churn in the telecommunications industry]. Explain the key steps involved, including [Suggest a specific step, e.g., data cleaning]. Discuss potential challenges or limitations, such as [Suggest a specific limitation, e.g., overfitting]. Structure your response in a clear, step-by-step manner. Maximum 800 words."
#
# *   **Change:** "application area" instead of "example" to be more precise.  "Data cleaning" instead of "data preprocessing" for broader understanding. "Overfitting" instead of "biased data" to be technically correct.
#
# **Option 2: Business-Focused Explanation with Real-World Examples**
#
# "Explain the business applications of {topic} in the [Suggest a specific industry, e.g., retail] industry to a non-technical audience with [Suggest a level of technical understanding, e.g., 'no prior experience with coding']. Focus on how {topic} can improve [Suggest a specific business outcome, e.g., inventory management efficiency] and [Suggest another specific business outcome, e.g., customer lifetime value]. Provide 2-3 real-world examples of companies successfully using {topic} in this industry. Avoid technical jargon and emphasize the potential return on investment (ROI). Maximum 750 words."
#
# *   **Change:** Added the level of technical understanding to be more specific. Clarified "inventory management efficiency" and "customer lifetime value" for clarity.
#
# **Option 3: Comparative Analysis with Strengths, Weaknesses, and Use Cases**
#
# "Compare and contrast {topic} with [Suggest a specific related concept, e.g., linear regression] and [Suggest another specific related concept, e.g., k-means clustering]. Present your comparison in a tabular format, highlighting the strengths, weaknesses, and appropriate use cases of each. For each concept, provide a simple example of a problem it could be used to solve, focusing on [Suggest a specific problem type, e.g., classification]. Explain the trade-offs between complexity, interpretability, and accuracy. Maximum 1000 words."
#
# *   **Change:** Replaced previous suggestions with more technically correct suggestions.  Changed "type of problem" to "problem type" for better flow.
#
# **Option 4: Deep Dive with Visual Component Description**
#
# "Explain {topic} to someone with [Suggest a target audience, e.g., undergraduate computer science student], assuming they understand basic [Suggest a prerequisite concept, e.g., programming concepts]. Use the analogy of [Suggest a specific analogy, e.g., a plumbing system] to explain the flow of information or processes. Describe in detail a diagram that would illustrate [Suggest a specific element to illustrate, e.g., the architecture of a convolutional neural network] or [Suggest another specific element to illustrate, e.g., the decision-making process of a decision tree]. Explain how the different components interact. Maximum 900 words."
#
# *   **Change:** Added a target audience to be more specific on the prompt. Changed the suggestion for a specific element to illustrate, e.g., the architecture of a convolutional neural network.
#
# **Option 5: Seeded, Beginner-Friendly Explanation with Summary**
#
# "Explain {topic} in a beginner-friendly and engaging way to a [Suggest a target audience, e.g., high school student]. Seed the response with the following sentence: '[Suggest a starting sentence to guide the response, e.g., {topic} is like teaching a computer to learn from examples.]' Use a concrete example related to [Suggest a specific application domain, e.g., image recognition] to illustrate the concept. Explain the key concepts and their importance in simple terms. Include a section on potential challenges or limitations. Summarize the main points in a concise conclusion. Maximum 700 words."
#
# *   **No Change:** This option is already well-structured.
#
# **General Notes:**
#
# *   **Consistency:** Review all options to ensure consistent terminology and phrasing (e.g., using "target audience" consistently).
# *   **Specificity:** The more specific the bracketed suggestions, the better the results will be. Think about the most common use cases and tailor the suggestions accordingly.
# *   **User Testing:** The best way to refine these prompts further is to test them with real users and gather feedback on the quality of the generated explanations.
#
# By incorporating these minor refinements, you'll have an even more powerful and effective set of prompt templates. Great work!
#
# Final refined prompt:
# This is a significant improvement! The prompt templates are now much more structured and provide helpful guidance for the user. The bracketed suggestions are excellent, as they offer concrete ideas and reduce ambiguity.  The inclusion of word limits is also a good practice.
#
# Here are a few minor suggestions for even further refinement, focusing on clarity and consistency:
#
# **Option 1: Structured Explanation with Analogy and Example**
#
# "Explain {topic} to someone with no prior knowledge. Use the analogy of [Suggest a specific analogy, e.g., a baker making bread] to illustrate the core concepts. Provide a concrete example related to [Suggest a specific application area, e.g., predicting customer churn in the telecommunications industry]. Explain the key steps involved, including [Suggest a specific step, e.g., data cleaning]. Discuss potential challenges or limitations, such as [Suggest a specific limitation, e.g., overfitting]. Structure your response in a clear, step-by-step manner. Maximum 800 words."
#
# *   **Change:** "application area" instead of "example" to be more precise.  "Data cleaning" instead of "data preprocessing" for broader understanding. "Overfitting" instead of "biased data" to be technically correct.
#
# **Option 2: Business-Focused Explanation with Real-World Examples**
#
# "Explain the business applications of {topic} in the [Suggest a specific industry, e.g., retail] industry to a non-technical audience with [Suggest a level of technical understanding, e.g., 'no prior experience with coding']. Focus on how {topic} can improve [Suggest a specific business outcome, e.g., inventory management efficiency] and [Suggest another specific business outcome, e.g., customer lifetime value]. Provide 2-3 real-world examples of companies successfully using {topic} in this industry. Avoid technical jargon and emphasize the potential return on investment (ROI). Maximum 750 words."
#
# *   **Change:** Added the level of technical understanding to be more specific. Clarified "inventory management efficiency" and "customer lifetime value" for clarity.
#
# **Option 3: Comparative Analysis with Strengths, Weaknesses, and Use Cases**
#
# "Compare and contrast {topic} with [Suggest a specific related concept, e.g., linear regression] and [Suggest another specific related concept, e.g., k-means clustering]. Present your comparison in a tabular format, highlighting the strengths, weaknesses, and appropriate use cases of each. For each concept, provide a simple example of a problem it could be used to solve, focusing on [Suggest a specific problem type, e.g., classification]. Explain the trade-offs between complexity, interpretability, and accuracy. Maximum 1000 words."
#
# *   **Change:** Replaced previous suggestions with more technically correct suggestions.  Changed "type of problem" to "problem type" for better flow.
#
# **Option 4: Deep Dive with Visual Component Description**
#
# "Explain {topic} to someone with [Suggest a target audience, e.g., undergraduate computer science student], assuming they understand basic [Suggest a prerequisite concept, e.g., programming concepts]. Use the analogy of [Suggest a specific analogy, e.g., a plumbing system] to explain the flow of information or processes. Describe in detail a diagram that would illustrate [Suggest a specific element to illustrate, e.g., the architecture of a convolutional neural network] or [Suggest another specific element to illustrate, e.g., the decision-making process of a decision tree]. Explain how the different components interact. Maximum 900 words."
#
# *   **Change:** Added a target audience to be more specific on the prompt. Changed the suggestion for a specific element to illustrate, e.g., the architecture of a convolutional neural network.
#
# **Option 5: Seeded, Beginner-Friendly Explanation with Summary**
#
# "Explain {topic} in a beginner-friendly and engaging way to a [Suggest a target audience, e.g., high school student]. Seed the response with the following sentence: '[Suggest a starting sentence to guide the response, e.g., {topic} is like teaching a computer to learn from examples.]' Use a concrete example related to [Suggest a specific application domain, e.g., image recognition] to illustrate the concept. Explain the key concepts and their importance in simple terms. Include a section on potential challenges or limitations. Summarize the main points in a concise conclusion. Maximum 700 words."
#
# *   **No Change:** This option is already well-structured.
#
# **General Notes:**
#
# *   **Consistency:** Review all options to ensure consistent terminology and phrasing (e.g., using "target audience" consistently).
# *   **Specificity:** The more specific the bracketed suggestions, the better the results will be. Think about the most common use cases and tailor the suggestions accordingly.
# *   **User Testing:** The best way to refine these prompts further is to test them with real users and gather feedback on the quality of the generated explanations.
#
# By incorporating these minor refinements, you'll have an even more powerful and effective set of prompt templates. Great work!

# %% [markdown]
# ### Comparing Original and Refined Prompts
# Let's compare the performance of the original and refined prompts.

# %%
original_response = generate_response(initial_prompt.format(topic="machine learning"))
refined_response = generate_response(refined_prompt.format(topic="machine learning"))

original_score = evaluate_response(original_response, criteria)
refined_score = evaluate_response(refined_response, criteria)

print(f"Original prompt score: {original_score:.2f}")
print(f"Refined prompt score: {refined_score:.2f}")
print(f"Improvement: {(refined_score - original_score):.2f} points")
# Out:
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Warning: Could not extract numeric score for engagement. Using default score of 5.
# Original prompt score: 7.00
# Refined prompt score: 8.33
# Improvement: 1.33 points
